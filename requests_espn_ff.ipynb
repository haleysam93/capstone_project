# %% [markdown]
# #### Sources
# https://stmorse.github.io/journal/espn-fantasy-python.html
#
# https://stmorse.github.io/journal/espn-fantasy-2-python.html
#
# https://stmorse.github.io/journal/espn-fantasy-3-python.html

# %%
import requests
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# Setup Constants
# identify the league
league_id = 272407
team_id = 7
season_id = 2018
# cookie stuff
ESPN_S2 = 'AEB8MCwqbL2YwOYOMJbCQ%2FvSMWfN6i2gKF1xbs4un0rSGOvw56jI4qJHzW8EtFAQbvrl1sptUylSwrblE4SxWu52F9sK1b%2BWoy3n8hZ0PvsTVNLVdwxzq%2FBRnOUBIrw73Vf8fMEqTjiXHoTXHhSStT0HI0DcZZuqoS%2Bi%2B0BFQARnuWpRs239t3XmDgzXHdRyBOtKfYcQXYpq%2BuvtXQ%2FfAxxt3SBMboeHlQi0uK0U0hkIT4cVCZdQ8%2FOVZDFlQk3KIY29wbJstYYILjYS8wp5iuM9'
ESPN_ATH = {"swid":"{7ADF0B7F-2028-4279-9F0B-7F20284279EC}"}
SWID = '{7ADF0B7F-2028-4279-9F0B-7F20284279EC}'

# %%
player_info = requests.get('http://games.espn.com/ffl/api/v2/playerInfo', 
                           params={'leagueId': league_id, 'seasonId': season_id, 'matchupPeriodId': 1},
                           cookies={'swid': SWID, 'espn_s2': ESPN_S2})

# %%
player_info.text
# Out:
# '\n\t<!DOCTYPE html>\n\t<html class="no-icon-fonts" lang="en">\n\t<head>\n\t\t<meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n<meta http-equiv="x-ua-compatible" content="IE=edge,chrome=1" />\n<meta name="viewport" content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n<link rel="canonical" href="https://www.espn.com/fantasy/football/" />\n<title>Fantasy Football - Leagues, Rankings, News, Picks & More - ESPN</title>\n<meta name="description" content="Play ESPN fantasy football for free. Create or join a fantasy football league, draft players, track rankings, watch highlights, get pick advice, and more!" />\n<meta name="news_keywords" content="fantasy football, free fantasy football, fantasy football rankings, fantasy football mock draft, fantasy football news, fantasy football picks, fantasy football videos, fantasy football advice" />\n<meta name="keywords" content="fantasy football, free fantasy football, fantasy football rankings, fantasy football mock draft, fantasy football news, fantasy football picks, fantasy football videos, fantasy football advice" />\n<meta property="fb:app_id" content="116656161708917" />\n<meta property="og:site_name" content="ESPN.com" />\n<meta property="og:url" content="https://www.espn.com/fantasy/football/" />\n<meta property="og:title" content="Fantasy Football - Leagues, Rankings, News, Picks & More - ESPN"/>\n<meta property="og:description" content="Play ESPN fantasy football for free. Create or join a fantasy football league, draft players, track rankings, watch highlights, get pick advice, and more!" />\n<meta property="og:image" content="https://a1.espncdn.com/combiner/i?img=%2Fi%2Fespn%2Fmisc_logos%2F500%2Fffl.png"/>\n<meta property="og:image:width" content="500" />\n<meta property="og:image:height" content="500" />\n<meta property="og:type" content="website" />\n<meta name="twitter:site" content="espn" />\n<meta name="twitter:url" content="https://www.espn.com/fantasy/football/" />\n<meta name="twitter:title" content="Fantasy Football - Leagues, Rankings, News, Picks & More - ESPN"/>\n<meta name="twitter:description" content="Play ESPN fantasy football for free. Create or join a fantasy football league, draft players, track rankings, watch highlights, get pick advice, and more!" />\n<meta name="twitter:card" content="summary">\n<meta name="twitter:app:name:iphone" content="ESPN"/>\n<meta name="twitter:app:id:iphone" content="317469184"/>\n<meta name="twitter:app:name:googleplay" content="ESPN"/>\n<meta name="twitter:app:id:googleplay" content="com.espn.score_center"/>\n<meta name="title" content="Fantasy Football - Leagues, Rankings, News, Picks & More - ESPN"/>\n<meta name="medium" content="index" />\n\n<!-- Indicate preferred brand name for Google to display -->\n<script type="application/ld+json">\n\t{\n\t\t"@context": "https://schema.org",\n\t\t"@type":    "WebSite",\n\t\t"name":     "ESPN",\n\t\t"url":      "https://www.espn.com/"\n\t}\n</script>\n<!--\n<PageMap>\n\t<DataObject type="document">\n\t\t<Attribute name="title">Fantasy Football - Leagues, Rankings, News, Picks & More</Attribute>\n\t</DataObject>\n\t<DataObject type="thumbnail">\n\t\t<Attribute name="src" value="https://a1.espncdn.com/combiner/i?img=%2Fi%2Fespn%2Fmisc_logos%2F500%2Fffl.png" />\n\t\t<Attribute name="width" value="500" />\n\t\t<Attribute name="height" value="500" />\n\t</DataObject>\n</PageMap>\n-->\n<link rel="alternate" hreflang="en-us" href="https://www.espn.com/fantasy/football/" />\n<link rel="alternate" hreflang="en-ww" href="https://global.espn.com/ffl/" />\n<link rel="alternate" hreflang="en-in" href="https://www.espn.in/ffl/" />\n<link rel="alternate" hreflang="en" href="https://www.espn.com/fantasy/football/" />\n<link rel="alternate" hreflang="en-au" href="https://www.espn.com.au/ffl/" />\n<link rel="alternate" hreflang="en-za" href="https://africa.espn.com/ffl/" />\n<link rel="alternate" hreflang="en-ph" href="https://tv5.espn.com/ffl/" />\n<link rel="alterna ...

# %%
player_info.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-98c5114f1468> in <module>()
# ----> 1 player_info.json()
#
# /home/sam/anaconda3/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     883                     # used.
#     884                     pass
# --> 885         return complexjson.loads(self.text, **kwargs)
#     886
#     887     @property
#
# /home/sam/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /home/sam/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /home/sam/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 2 (char 2)

# %%
player_info = player_info.json()['playerInfo']
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-daac8511a51c> in <module>()
# ----> 1 player_info = player_info.json()['playerInfo']
#
# /home/sam/anaconda3/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     883                     # used.
#     884                     pass
# --> 885         return complexjson.loads(self.text, **kwargs)
#     886
#     887     @property
#
# /home/sam/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /home/sam/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /home/sam/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 2 (char 2)

# %%
player_info
# Out:
# {'players': [{'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 1.4,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Todd',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '30',
#     'lastName': 'Gurley II',
#     'lastNewsDate': '2018-11-29T01:07:28.000Z',
#     'lastVideoDate': '2017-12-31T15:21:49.853Z',
#     'percentChange': 0.00437,
#     'percentOwned': 99.96916,
#     'percentStarted': 76.62026,
#     'playerId': 17683,
#     'proTeamId': 14,
#     'sportsId': 2977644,
#     'tickerId': 2977644,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/ffl/CoachGruden-ChipWass/gruden-15.svg',
#     'teamAbbrev': 'dumb',
#     'teamId': 5,
#     'teamLocation': 'Domestic',
#     'teamNickname': 'Violins',
#     'waiverRank': 2},
#    'teamId': 5,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 5.8,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Alvin',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '41',
#     'lastName': 'Kamara',
#     'lastNewsDate': '2018-11-23T04:45:45.000Z',
#     'lastVideoDate': '2017-12-17T08:25:27.467Z',
#     'percentChange': -0.00072,
#     'percentOwned': 99.9612,
#     'percentStarted': 99.49029,
#     'playerId': 18187,
#     'proTeamId': 18,
#     'sportsId': 3054850,
#     'tickerId': 3054850,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/s/ffllm/logos/SmackTalk-LeoEspinosa/u_mad_bro-09.svg',
#     'teamAbbrev': 'QUIN',
#     'teamId': 8,
#     'teamLocation': 'Charlottesville',
#     'teamNickname': 'Challengers',
#     'waiverRank': 1},
#    'teamId': 8,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 5.5,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Antonio',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '84',
#     'lastName': 'Brown',
#     'lastNewsDate': '2018-11-26T01:17:29.000Z',
#     'lastVideoDate': '2017-12-28T19:14:46.307Z',
#     'percentChange': -0.00193,
#     'percentOwned': 99.95752,
#     'percentStarted': 99.22573,
#     'playerId': 13934,
#     'proTeamId': 23,
#     'sportsId': 13934,
#     'tickerId': 2276860,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_hot-dog.svg',
#     'teamAbbrev': 'Livi',
#     'teamId': 9,
#     'teamLocation': 'Sugar ',
#     'teamNickname': 'Sugar',
#     'waiverRank': 4},
#    'teamId': 9,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 4,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Ezekiel',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '21',
#     'lastName': 'Elliott',
#     'lastNewsDate': '2018-11-26T23:00:26.000Z',
#     'lastVideoDate': '2017-12-23T15:55:01.697Z',
#     'percentChange': -8e-05,
#     'percentOwned': 99.95597,
#     'percentStarted': 99.41027,
#     'playerId': 17797,
#     'proTeamId': 6,
#     'sportsId': 3051392,
#     'tickerId': 3051392,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://consequenceofsound.files.wordpress.com/2017/08/martin-shkreli.png?w=807',
#     'teamAbbrev': 'VETO',
#     'teamId': 2,
#     'teamLocation': 'Crooked Logans',
#     'teamNickname': 'Colluders',
#     'waiverRank': 7},
#    'teamId': 2,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 5.3,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Saquon',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '26',
#     'lastName': 'Barkley',
#     'lastNewsDate': '2018-11-25T21:50:50.000Z',
#     'lastVideoDate': '1970-01-01T00:00:00.000Z',
#     'percentChange': 0.0011,
#     'percentOwned': 99.95347,
#     'percentStarted': 99.35224,
#     'playerId': 18567,
#     'proTeamId': 19,
#     'sportsId': 3929630,
#     'tickerId': 3929630,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'teamAbbrev': 'HALE',
#     'teamId': 7,
#     'teamLocation': 'Logans',
#     'teamNickname': 'Fake ID',
#     'waiverRank': 10},
#    'teamId': 7,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 4,
#     'draftRank': 27.9,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [6, 23, 20],
#     'firstName': 'Travis',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '87',
#     'lastName': 'Kelce',
#     'lastNewsDate': '2018-11-20T06:22:58.000Z',
#     'lastVideoDate': '2017-12-15T13:47:11.067Z',
#     'percentChange': 0.01064,
#     'percentOwned': 99.94874,
#     'percentStarted': 75.63149,
#     'playerId': 15847,
#     'proTeamId': 12,
#     'sportsId': 15847,
#     'tickerId': 2309410,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'http://rs403.pbsrc.com/albums/pp118/wright1304/dallassucks.gif~c200',
#     'teamAbbrev': 'VIEL',
#     'teamId': 1,
#     'teamLocation': 'Drain the ',
#     'teamNickname': 'Fantasy Swamp',
#     'waiverRank': 6},
#    'teamId': 1,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 9.1,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Julio',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '11',
#     'lastName': 'Jones',
#     'lastNewsDate': '2018-11-23T05:23:46.000Z',
#     'lastVideoDate': '2017-12-20T06:34:44.180Z',
#     'percentChange': -0.00253,
#     'percentOwned': 99.94873,
#     'percentStarted': 99.19341,
#     'playerId': 13982,
#     'proTeamId': 1,
#     'sportsId': 13982,
#     'tickerId': 2311083,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'http://rs403.pbsrc.com/albums/pp118/wright1304/dallassucks.gif~c200',
#     'teamAbbrev': 'VIEL',
#     'teamId': 1,
#     'teamLocation': 'Drain the ',
#     'teamNickname': 'Fantasy Swamp',
#     'waiverRank': 6},
#    'teamId': 1,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 11.5,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'DeAndre',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '10',
#     'lastName': 'Hopkins',
#     'lastNewsDate': '2018-11-29T22:23:01.000Z',
#     'lastVideoDate': '2017-12-31T13:46:22.673Z',
#     'percentChange': -0.00072,
#     'percentOwned': 99.94591,
#     'percentStarted': 98.18686,
#     'playerId': 15795,
#     'proTeamId': 34,
#     'sportsId': 15795,
#     'tickerId': 2512410,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'teamAbbrev': 'TMS',
#     'teamId': 4,
#     'teamLocation': 'Donnie Jones',
#     'teamNickname': "Bag O' Bones",
#     'waiverRank': 8},
#    'teamId': 4,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 17.9,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Michael',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '13',
#     'lastName': 'Thomas',
#     'lastNewsDate': '2018-11-23T07:28:07.000Z',
#     'lastVideoDate': '2017-11-19T05:13:20.143Z',
#     'percentChange': -0.00095,
#     'percentOwned': 99.94565,
#     'percentStarted': 99.12395,
#     'playerId': 17834,
#     'proTeamId': 18,
#     'sportsId': 2976316,
#     'tickerId': 2976316,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://consequenceofsound.files.wordpress.com/2017/08/martin-shkreli.png?w=807',
#     'teamAbbrev': 'VETO',
#     'teamId': 2,
#     'teamLocation': 'Crooked Logans',
#     'teamNickname': 'Colluders',
#     'waiverRank': 7},
#    'teamId': 2,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 4,
#     'draftRank': 36.7,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [6, 23, 20],
#     'firstName': 'Zach',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '86',
#     'lastName': 'Ertz',
#     'lastNewsDate': '2018-11-25T21:43:21.000Z',
#     'lastVideoDate': '2017-12-15T07:48:43.700Z',
#     'percentChange': 0.00099,
#     'percentOwned': 99.94252,
#     'percentStarted': 98.47577,
#     'playerId': 15835,
#     'proTeamId': 21,
#     'sportsId': 15835,
#     'tickerId': 2468605,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StarWarsTheForceAwakens-ToddDetwiler/ESPN_Star_Wars_17a.svg',
#     'teamAbbrev': 'TK',
#     'teamId': 10,
#     'teamLocation': 'Thee',
#     'teamNickname': 'Klaus',
#     'waiverRank': 9},
#    'teamId': 10,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 8.9,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Kareem',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '27',
#     'lastName': 'Hunt',
#     'lastNewsDate': '2018-11-20T06:07:56.000Z',
#     'lastVideoDate': '2017-12-24T16:10:14.823Z',
#     'percentChange': 0.0077,
#     'percentOwned': 99.94222,
#     'percentStarted': 74.49722,
#     'playerId': 18225,
#     'proTeamId': 12,
#     'sportsId': 3059915,
#     'tickerId': 3059915,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://sportshub.cbsistatic.com/i/r/2017/08/22/f8a2988e-2e48-4eec-961f-7bacd05baa06/thumbnail/770x433/192b9a115ce735dc79f956c67f4c788f/carson-wentz-eagles.jpg',
#     'teamAbbrev': 'Wenz',
#     'teamId': 6,
#     'teamLocation': 'King Wentz of',
#     'teamNickname': 'Wentzylvania',
#     'waiverRank': 3},
#    'teamId': 6,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 11.3,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Odell',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '13',
#     'lastName': 'Beckham Jr.',
#     'lastNewsDate': '2018-11-25T21:31:13.000Z',
#     'lastVideoDate': '2017-09-12T20:52:34.137Z',
#     'percentChange': -0.00153,
#     'percentOwned': 99.94154,
#     'percentStarted': 98.25618,
#     'playerId': 16733,
#     'proTeamId': 19,
#     'sportsId': 16733,
#     'tickerId': 2577289,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'teamAbbrev': 'TMS',
#     'teamId': 4,
#     'teamLocation': 'Donnie Jones',
#     'teamNickname': "Bag O' Bones",
#     'waiverRank': 8},
#    'teamId': 4,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 18.1,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Christian',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '22',
#     'lastName': 'McCaffrey',
#     'lastNewsDate': '2018-11-25T21:48:30.000Z',
#     'lastVideoDate': '2017-12-07T06:33:08.323Z',
#     'percentChange': 0.00532,
#     'percentOwned': 99.93335,
#     'percentStarted': 99.45242,
#     'playerId': 18279,
#     'proTeamId': 29,
#     'sportsId': 3117251,
#     'tickerId': 3117251,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_hot-dog.svg',
#     'teamAbbrev': 'Livi',
#     'teamId': 9,
#     'teamLocation': 'Sugar ',
#     'teamNickname': 'Sugar',
#     'waiverRank': 4},
#    'teamId': 9,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 3.3,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'David',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '31',
#     'lastName': 'Johnson',
#     'lastNewsDate': '2018-11-26T01:34:57.000Z',
#     'lastVideoDate': '2017-12-31T13:37:54.683Z',
#     'percentChange': -0.00799,
#     'percentOwned': 99.9221,
#     'percentStarted': 94.52581,
#     'playerId': 17442,
#     'proTeamId': 22,
#     'sportsId': 2508176,
#     'tickerId': 2508176,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StarWarsTheForceAwakens-ToddDetwiler/ESPN_Star_Wars_17a.svg',
#     'teamAbbrev': 'TK',
#     'teamId': 10,
#     'teamLocation': 'Thee',
#     'teamNickname': 'Klaus',
#     'waiverRank': 9},
#    'teamId': 10,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 34.1,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Adam',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '19',
#     'lastName': 'Thielen',
#     'lastNewsDate': '2018-11-29T22:04:01.000Z',
#     'lastVideoDate': '2017-12-23T15:41:08.147Z',
#     'percentChange': 0.00258,
#     'percentOwned': 99.89057,
#     'percentStarted': 98.3726,
#     'playerId': 17178,
#     'proTeamId': 16,
#     'sportsId': 16460,
#     'tickerId': 3031795,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_beer.svg',
#     'teamAbbrev': 'ROB',
#     'teamId': 3,
#     'teamLocation': 'Team',
#     'teamNickname': 'Cavanaugh',
#     'waiverRank': 5},
#    'teamId': 3,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 29.5,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Tyreek',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '10',
#     'lastName': 'Hill',
#     'lastNewsDate': '2018-11-20T06:18:02.000Z',
#     'lastVideoDate': '2017-12-16T15:57:25.857Z',
#     'percentChange': 0.00216,
#     'percentOwned': 99.8832,
#     'percentStarted': 76.22839,
#     'playerId': 17929,
#     'proTeamId': 12,
#     'sportsId': 3116406,
#     'tickerId': 3116406,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/ffl/CoachGruden-ChipWass/gruden-15.svg',
#     'teamAbbrev': 'dumb',
#     'teamId': 5,
#     'teamLocation': 'Domestic',
#     'teamNickname': 'Violins',
#     'waiverRank': 2},
#    'teamId': 5,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 17.1,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Keenan',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '13',
#     'lastName': 'Allen',
#     'lastNewsDate': '2018-11-26T01:10:39.000Z',
#     'lastVideoDate': '2017-12-20T06:23:20.880Z',
#     'percentChange': 0.00224,
#     'percentOwned': 99.87881,
#     'percentStarted': 95.82909,
#     'playerId': 15818,
#     'proTeamId': 24,
#     'sportsId': 15818,
#     'tickerId': 2512219,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_beer.svg',
#     'teamAbbrev': 'ROB',
#     'teamId': 3,
#     'teamLocation': 'Team',
#     'teamNickname': 'Cavanaugh',
#     'waiverRank': 5},
#    'teamId': 3,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 24.7,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Davante',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '17',
#     'lastName': 'Adams',
#     'lastNewsDate': '2018-11-26T07:03:06.000Z',
#     'lastVideoDate': '2017-12-23T15:40:56.707Z',
#     'percentChange': 0.00108,
#     'percentOwned': 99.81719,
#     'percentStarted': 98.56677,
#     'playerId': 16800,
#     'proTeamId': 9,
#     'sportsId': 16800,
#     'tickerId': 2589699,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://sportshub.cbsistatic.com/i/r/2017/08/22/f8a2988e-2e48-4eec-961f-7bacd05baa06/thumbnail/770x433/192b9a115ce735dc79f956c67f4c788f/carson-wentz-eagles.jpg',
#     'teamAbbrev': 'Wenz',
#     'teamId': 6,
#     'teamLocation': 'King Wentz of',
#     'teamNickname': 'Wentzylvania',
#     'waiverRank': 3},
#    'teamId': 6,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 25.9,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Mike',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '13',
#     'lastName': 'Evans',
#     'lastNewsDate': '2018-11-25T21:32:05.000Z',
#     'lastVideoDate': '2017-12-23T16:03:53.293Z',
#     'percentChange': -0.0051,
#     'percentOwned': 99.67053,
#     'percentStarted': 95.03032,
#     'playerId': 16737,
#     'proTeamId': 27,
#     'sportsId': 16737,
#     'tickerId': 2578714,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StarWarsTheForceAwakens-ToddDetwiler/ESPN_Star_Wars_17a.svg',
#     'teamAbbrev': 'TK',
#     'teamId': 10,
#     'teamLocation': 'Thee',
#     'teamNickname': 'Klaus',
#     'waiverRank': 9},
#    'teamId': 10,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 1,
#     'draftRank': 22.2,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [0, 20],
#     'firstName': 'Aaron',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '12',
#     'lastName': 'Rodgers',
#     'lastNewsDate': '2018-11-26T06:19:36.000Z',
#     'lastVideoDate': '2018-01-17T01:06:49.053Z',
#     'percentChange': -0.13201,
#     'percentOwned': 99.55704,
#     'percentStarted': 76.46082,
#     'playerId': 8439,
#     'proTeamId': 9,
#     'sportsId': 8439,
#     'tickerId': 2129320,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_hot-dog.svg',
#     'teamAbbrev': 'Livi',
#     'teamId': 9,
#     'teamLocation': 'Sugar ',
#     'teamNickname': 'Sugar',
#     'waiverRank': 4},
#    'teamId': 9,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 32.9,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Stefon',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '14',
#     'lastName': 'Diggs',
#     'lastNewsDate': '2018-11-29T19:41:52.000Z',
#     'lastVideoDate': '2017-12-10T07:34:42.100Z',
#     'percentChange': 0.08115,
#     'percentOwned': 99.4732,
#     'percentStarted': 93.44188,
#     'playerId': 17676,
#     'proTeamId': 16,
#     'sportsId': 2976212,
#     'tickerId': 2976212,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://sportshub.cbsistatic.com/i/r/2017/08/22/f8a2988e-2e48-4eec-961f-7bacd05baa06/thumbnail/770x433/192b9a115ce735dc79f956c67f4c788f/carson-wentz-eagles.jpg',
#     'teamAbbrev': 'Wenz',
#     'teamId': 6,
#     'teamLocation': 'King Wentz of',
#     'teamNickname': 'Wentzylvania',
#     'waiverRank': 3},
#    'teamId': 6,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 4,
#     'draftRank': 18.8,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [6, 23, 20],
#     'firstName': 'Rob',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '87',
#     'lastName': 'Gronkowski',
#     'lastNewsDate': '2018-11-29T21:05:55.000Z',
#     'lastVideoDate': '2018-01-17T01:05:55.110Z',
#     'percentChange': 0.46691,
#     'percentOwned': 99.31166,
#     'percentStarted': 80.95122,
#     'playerId': 13229,
#     'proTeamId': 17,
#     'sportsId': 13229,
#     'tickerId': 2267819,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://sportshub.cbsistatic.com/i/r/2017/08/22/f8a2988e-2e48-4eec-961f-7bacd05baa06/thumbnail/770x433/192b9a115ce735dc79f956c67f4c788f/carson-wentz-eagles.jpg',
#     'teamAbbrev': 'Wenz',
#     'teamId': 6,
#     'teamLocation': 'King Wentz of',
#     'teamNickname': 'Wentzylvania',
#     'waiverRank': 3},
#    'teamId': 6,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 29.9,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Joe',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '28',
#     'lastName': 'Mixon',
#     'lastNewsDate': '2018-11-25T22:43:57.000Z',
#     'lastVideoDate': '2017-12-31T16:16:36.587Z',
#     'percentChange': -0.01455,
#     'percentOwned': 99.19351,
#     'percentStarted': 89.27879,
#     'playerId': 18193,
#     'proTeamId': 4,
#     'sportsId': 3116385,
#     'tickerId': 3116385,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'teamAbbrev': 'TMS',
#     'teamId': 4,
#     'teamLocation': 'Donnie Jones',
#     'teamNickname': "Bag O' Bones",
#     'waiverRank': 8},
#    'teamId': 4,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 1,
#     'draftRank': 46.6,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [0, 20],
#     'firstName': 'Cam',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '1',
#     'lastName': 'Newton',
#     'lastNewsDate': '2018-11-29T19:56:32.000Z',
#     'lastVideoDate': '2017-12-16T07:21:07.373Z',
#     'percentChange': 0.03795,
#     'percentOwned': 99.17587,
#     'percentStarted': 86.42682,
#     'playerId': 13994,
#     'proTeamId': 29,
#     'sportsId': 13994,
#     'tickerId': 2267163,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StarWarsTheForceAwakens-ToddDetwiler/ESPN_Star_Wars_17a.svg',
#     'teamAbbrev': 'TK',
#     'teamId': 10,
#     'teamLocation': 'Thee',
#     'teamNickname': 'Klaus',
#     'waiverRank': 9},
#    'teamId': 10,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 1,
#     'draftRank': 105.5,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [0, 20],
#     'firstName': 'Patrick',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '15',
#     'lastName': 'Mahomes',
#     'lastNewsDate': '2018-11-20T05:55:34.000Z',
#     'lastVideoDate': '2018-03-18T05:13:49.213Z',
#     'percentChange': 0.0516,
#     'percentOwned': 99.17136,
#     'percentStarted': 77.33657,
#     'playerId': 18210,
#     'proTeamId': 12,
#     'sportsId': 3139477,
#     'tickerId': 3139477,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_hot-dog.svg',
#     'teamAbbrev': 'Livi',
#     'teamId': 9,
#     'teamLocation': 'Sugar ',
#     'teamNickname': 'Sugar',
#     'waiverRank': 4},
#    'teamId': 9,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 15.8,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Melvin',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 4,
#     'isActive': True,
#     'isIREligible': True,
#     'jersey': '28',
#     'lastName': 'Gordon',
#     'lastNewsDate': '2018-11-26T19:21:38.000Z',
#     'lastVideoDate': '2017-12-23T15:47:40.470Z',
#     'percentChange': -0.77557,
#     'percentOwned': 99.16118,
#     'percentStarted': 20.29693,
#     'playerId': 17586,
#     'proTeamId': 24,
#     'sportsId': 2576434,
#     'tickerId': 2576434,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'http://rs403.pbsrc.com/albums/pp118/wright1304/dallassucks.gif~c200',
#     'teamAbbrev': 'VIEL',
#     'teamId': 1,
#     'teamLocation': 'Drain the ',
#     'teamNickname': 'Fantasy Swamp',
#     'waiverRank': 6},
#    'teamId': 1,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 87,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'James',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '30',
#     'lastName': 'Conner',
#     'lastNewsDate': '2018-11-26T01:49:41.000Z',
#     'lastVideoDate': '2017-12-20T06:36:46.370Z',
#     'percentChange': 0.04087,
#     'percentOwned': 99.12986,
#     'percentStarted': 96.25625,
#     'playerId': 18236,
#     'proTeamId': 23,
#     'sportsId': 3045147,
#     'tickerId': 3045147,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_beer.svg',
#     'teamAbbrev': 'ROB',
#     'teamId': 3,
#     'teamLocation': 'Team',
#     'teamNickname': 'Cavanaugh',
#     'waiverRank': 5},
#    'teamId': 3,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 52.1,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'JuJu',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '19',
#     'lastName': 'Smith-Schuster',
#     'lastNewsDate': '2018-11-26T03:47:25.000Z',
#     'lastVideoDate': '2017-12-31T13:45:30.403Z',
#     'percentChange': 0.07424,
#     'percentOwned': 98.93203,
#     'percentStarted': 93.97953,
#     'playerId': 18306,
#     'proTeamId': 23,
#     'sportsId': 3120348,
#     'tickerId': 3120348,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StarWarsTheForceAwakens-ToddDetwiler/ESPN_Star_Wars_17a.svg',
#     'teamAbbrev': 'TK',
#     'teamId': 10,
#     'teamLocation': 'Thee',
#     'teamNickname': 'Klaus',
#     'waiverRank': 9},
#    'teamId': 10,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 20.6,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'A.J.',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '18',
#     'lastName': 'Green',
#     'lastNewsDate': '2018-11-29T19:34:09.000Z',
#     'lastVideoDate': '2017-12-21T19:38:44.763Z',
#     'percentChange': 0.09004,
#     'percentOwned': 98.80227,
#     'percentStarted': 40.67025,
#     'playerId': 13983,
#     'proTeamId': 4,
#     'sportsId': 13983,
#     'tickerId': 2311353,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://consequenceofsound.files.wordpress.com/2017/08/martin-shkreli.png?w=807',
#     'teamAbbrev': 'VETO',
#     'teamId': 2,
#     'teamLocation': 'Crooked Logans',
#     'teamNickname': 'Colluders',
#     'waiverRank': 7},
#    'teamId': 2,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 33.3,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'T.Y.',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '13',
#     'lastName': 'Hilton',
#     'lastNewsDate': '2018-11-29T20:32:55.000Z',
#     'lastVideoDate': '2017-12-23T15:40:29.797Z',
#     'percentChange': 0.22262,
#     'percentOwned': 98.69537,
#     'percentStarted': 88.27034,
#     'playerId': 14924,
#     'proTeamId': 11,
#     'sportsId': 14924,
#     'tickerId': 2316073,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'teamAbbrev': 'HALE',
#     'teamId': 7,
#     'teamLocation': 'Logans',
#     'teamNickname': 'Fake ID',
#     'waiverRank': 10},
#    'teamId': 7,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 13.1,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Leonard',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 13,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '27',
#     'lastName': 'Fournette',
#     'lastNewsDate': '2018-11-28T14:14:24.000Z',
#     'lastVideoDate': '2017-12-30T06:32:22.127Z',
#     'percentChange': -0.01462,
#     'percentOwned': 98.62869,
#     'percentStarted': 20.833,
#     'playerId': 18218,
#     'proTeamId': 30,
#     'sportsId': 3115364,
#     'tickerId': 3115364,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'teamAbbrev': 'HALE',
#     'teamId': 7,
#     'teamLocation': 'Logans',
#     'teamNickname': 'Fake ID',
#     'waiverRank': 10},
#    'teamId': 7,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 52.6,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Brandin',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '12',
#     'lastName': 'Cooks',
#     'lastNewsDate': '2018-11-20T05:24:06.000Z',
#     'lastVideoDate': '2017-12-23T15:49:26.010Z',
#     'percentChange': -0.01416,
#     'percentOwned': 98.55286,
#     'percentStarted': 61.79558,
#     'playerId': 16731,
#     'proTeamId': 14,
#     'sportsId': 16731,
#     'tickerId': 2577001,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://consequenceofsound.files.wordpress.com/2017/08/martin-shkreli.png?w=807',
#     'teamAbbrev': 'VETO',
#     'teamId': 2,
#     'teamLocation': 'Crooked Logans',
#     'teamNickname': 'Colluders',
#     'waiverRank': 7},
#    'teamId': 2,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 1,
#     'draftRank': 67.2,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [0, 20],
#     'firstName': 'Drew',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '9',
#     'lastName': 'Brees',
#     'lastNewsDate': '2018-11-23T05:43:12.000Z',
#     'lastVideoDate': '2017-12-07T16:15:31.237Z',
#     'percentChange': 0.18683,
#     'percentOwned': 98.31599,
#     'percentStarted': 82.67706,
#     'playerId': 2580,
#     'proTeamId': 18,
#     'sportsId': 2580,
#     'tickerId': 13034,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'http://rs403.pbsrc.com/albums/pp118/wright1304/dallassucks.gif~c200',
#     'teamAbbrev': 'VIEL',
#     'teamId': 1,
#     'teamLocation': 'Drain the ',
#     'teamNickname': 'Fantasy Swamp',
#     'waiverRank': 6},
#    'teamId': 1,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 1,
#     'draftRank': 23.7,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [0, 20],
#     'firstName': 'Tom',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '12',
#     'lastName': 'Brady',
#     'lastNewsDate': '2018-11-29T22:07:59.000Z',
#     'lastVideoDate': '2017-12-15T07:56:35.553Z',
#     'percentChange': -0.62736,
#     'percentOwned': 97.60523,
#     'percentStarted': 40.89364,
#     'playerId': 2330,
#     'proTeamId': 17,
#     'sportsId': 2330,
#     'tickerId': 1870523,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/s/ffllm/logos/SmackTalk-LeoEspinosa/u_mad_bro-09.svg',
#     'teamAbbrev': 'QUIN',
#     'teamId': 8,
#     'teamLocation': 'Charlottesville',
#     'teamNickname': 'Challengers',
#     'waiverRank': 1},
#    'teamId': 8,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 16,
#     'draftRank': 131.2,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [16, 20],
#     'firstName': 'Bears',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'lastName': 'D/ST',
#     'lastNewsDate': '2012-11-06T19:22:25.114Z',
#     'lastVideoDate': '1970-01-01T00:00:00.000Z',
#     'percentChange': 0.13236,
#     'percentOwned': 97.58416,
#     'percentStarted': 93.66091,
#     'playerId': 60003,
#     'proTeamId': 3,
#     'sportsId': 60003,
#     'tickerId': 0,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/ffl/CoachGruden-ChipWass/gruden-15.svg',
#     'teamAbbrev': 'dumb',
#     'teamId': 5,
#     'teamLocation': 'Domestic',
#     'teamNickname': 'Violins',
#     'waiverRank': 2},
#    'teamId': 5,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 72.2,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Robert',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '17',
#     'lastName': 'Woods',
#     'lastNewsDate': '2018-11-20T05:39:33.000Z',
#     'lastVideoDate': '2017-12-23T16:04:59.897Z',
#     'percentChange': -0.0589,
#     'percentOwned': 97.39909,
#     'percentStarted': 57.97938,
#     'playerId': 15880,
#     'proTeamId': 14,
#     'sportsId': 15880,
#     'tickerId': 2510592,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StarWarsTheForceAwakens-ToddDetwiler/ESPN_Star_Wars_17a.svg',
#     'teamAbbrev': 'TK',
#     'teamId': 10,
#     'teamLocation': 'Thee',
#     'teamNickname': 'Klaus',
#     'waiverRank': 9},
#    'teamId': 10,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 5,
#     'draftRank': 143.3,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [17, 20],
#     'firstName': 'Wil',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '3',
#     'lastName': 'Lutz',
#     'lastNewsDate': '2018-11-28T21:11:20.000Z',
#     'lastVideoDate': '1970-01-01T00:00:00.000Z',
#     'percentChange': -0.64769,
#     'percentOwned': 97.17628,
#     'percentStarted': 92.76876,
#     'playerId': 18104,
#     'proTeamId': 18,
#     'sportsId': 2985659,
#     'tickerId': 2985659,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'http://rs403.pbsrc.com/albums/pp118/wright1304/dallassucks.gif~c200',
#     'teamAbbrev': 'VIEL',
#     'teamId': 1,
#     'teamLocation': 'Drain the ',
#     'teamNickname': 'Fantasy Swamp',
#     'waiverRank': 6},
#    'teamId': 1,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 0,
#    'player': {'defaultPositionId': 4,
#     'draftRank': 121.8,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [6, 23, 20],
#     'firstName': 'George',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '85',
#     'lastName': 'Kittle',
#     'lastNewsDate': '2018-11-25T21:55:46.000Z',
#     'lastVideoDate': '2017-10-09T17:04:07.960Z',
#     'percentChange': 0.47622,
#     'percentOwned': 96.99022,
#     'percentStarted': 83.31044,
#     'playerId': 18292,
#     'proTeamId': 25,
#     'sportsId': 3040151,
#     'tickerId': 3040151,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 2,
#    'team': {'teamAbbrev': 'WA',
#     'teamId': -1,
#     'teamNickname': 'Waivers',
#     'waiverRank': 0},
#    'teamId': -1,
#    'waiverProcessDate': '2018-12-05T08:00:00.000Z',
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 43.8,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Amari',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '19',
#     'lastName': 'Cooper',
#     'lastNewsDate': '2018-11-23T03:35:49.000Z',
#     'lastVideoDate': '2017-12-24T22:33:23.657Z',
#     'percentChange': 1.4484,
#     'percentOwned': 96.49199,
#     'percentStarted': 76.45161,
#     'playerId': 17677,
#     'proTeamId': 6,
#     'sportsId': 2976499,
#     'tickerId': 2976499,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'teamAbbrev': 'HALE',
#     'teamId': 7,
#     'teamLocation': 'Logans',
#     'teamNickname': 'Fake ID',
#     'waiverRank': 10},
#    'teamId': 7,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 66.7,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Emmanuel',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '10',
#     'lastName': 'Sanders',
#     'lastNewsDate': '2018-11-26T03:23:56.000Z',
#     'lastVideoDate': '2017-12-14T16:05:26.897Z',
#     'percentChange': 0.12321,
#     'percentOwned': 96.20656,
#     'percentStarted': 76.8257,
#     'playerId': 13295,
#     'proTeamId': 7,
#     'sportsId': 13295,
#     'tickerId': 2181527,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'teamAbbrev': 'HALE',
#     'teamId': 7,
#     'teamLocation': 'Logans',
#     'teamNickname': 'Fake ID',
#     'waiverRank': 10},
#    'teamId': 7,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 0,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 170,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Nick',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '24',
#     'lastName': 'Chubb',
#     'lastNewsDate': '2018-11-25T22:18:50.000Z',
#     'lastVideoDate': '1970-01-01T00:00:00.000Z',
#     'percentChange': 1.07216,
#     'percentOwned': 96.17605,
#     'percentStarted': 88.85733,
#     'playerId': 18592,
#     'proTeamId': 5,
#     'sportsId': 3128720,
#     'tickerId': 3128720,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 2,
#    'team': {'teamAbbrev': 'WA',
#     'teamId': -1,
#     'teamNickname': 'Waivers',
#     'waiverRank': 0},
#    'teamId': -1,
#    'waiverProcessDate': '2018-12-05T08:00:00.000Z',
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 13.6,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Dalvin',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '33',
#     'lastName': 'Cook',
#     'lastNewsDate': '2018-11-26T08:04:53.000Z',
#     'lastVideoDate': '2017-10-02T16:29:20.763Z',
#     'percentChange': 0.16994,
#     'percentOwned': 96.04119,
#     'percentStarted': 67.73215,
#     'playerId': 18260,
#     'proTeamId': 16,
#     'sportsId': 3116593,
#     'tickerId': 3116593,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/s/ffllm/logos/SmackTalk-LeoEspinosa/u_mad_bro-09.svg',
#     'teamAbbrev': 'QUIN',
#     'teamId': 8,
#     'teamLocation': 'Charlottesville',
#     'teamNickname': 'Challengers',
#     'waiverRank': 1},
#    'teamId': 8,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 16,
#     'draftRank': 95.6,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [16, 20],
#     'firstName': 'Rams',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'lastName': 'D/ST',
#     'lastNewsDate': '1970-01-01T00:00:00.000Z',
#     'lastVideoDate': '2018-03-09T15:39:11.310Z',
#     'percentChange': 3.77086,
#     'percentOwned': 96.02664,
#     'percentStarted': 61.2928,
#     'playerId': 60014,
#     'proTeamId': 14,
#     'sportsId': 60014,
#     'tickerId': 0,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/s/ffllm/logos/SmackTalk-LeoEspinosa/u_mad_bro-09.svg',
#     'teamAbbrev': 'QUIN',
#     'teamId': 8,
#     'teamLocation': 'Charlottesville',
#     'teamNickname': 'Challengers',
#     'waiverRank': 1},
#    'teamId': 8,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 66.4,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Mark',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '22',
#     'lastName': 'Ingram II',
#     'lastNewsDate': '2018-11-23T06:47:06.000Z',
#     'lastVideoDate': '2017-12-07T16:15:53.697Z',
#     'percentChange': -0.0603,
#     'percentOwned': 95.99702,
#     'percentStarted': 61.51027,
#     'playerId': 13981,
#     'proTeamId': 18,
#     'sportsId': 13981,
#     'tickerId': 2311079,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'http://rs403.pbsrc.com/albums/pp118/wright1304/dallassucks.gif~c200',
#     'teamAbbrev': 'VIEL',
#     'teamId': 1,
#     'teamLocation': 'Drain the ',
#     'teamNickname': 'Fantasy Swamp',
#     'waiverRank': 6},
#    'teamId': 1,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 5,
#     'draftRank': 93.5,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [17, 20],
#     'firstName': 'Stephen',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '3',
#     'lastName': 'Gostkowski',
#     'lastNewsDate': '2018-11-26T18:13:36.000Z',
#     'lastVideoDate': '1970-01-01T00:00:00.000Z',
#     'percentChange': 0.78165,
#     'percentOwned': 95.76241,
#     'percentStarted': 76.61469,
#     'playerId': 9704,
#     'proTeamId': 17,
#     'sportsId': 9704,
#     'tickerId': 2113115,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_hot-dog.svg',
#     'teamAbbrev': 'Livi',
#     'teamId': 9,
#     'teamLocation': 'Sugar ',
#     'teamNickname': 'Sugar',
#     'waiverRank': 4},
#    'teamId': 9,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 124.4,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'James',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '28',
#     'lastName': 'White',
#     'lastNewsDate': '2018-11-26T17:45:57.000Z',
#     'lastVideoDate': '2017-12-06T07:10:45.500Z',
#     'percentChange': -0.79422,
#     'percentOwned': 95.7076,
#     'percentStarted': 55.15306,
#     'playerId': 16913,
#     'proTeamId': 17,
#     'sportsId': 16913,
#     'tickerId': 2515636,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StarWarsTheForceAwakens-ToddDetwiler/ESPN_Star_Wars_17a.svg',
#     'teamAbbrev': 'TK',
#     'teamId': 10,
#     'teamLocation': 'Thee',
#     'teamNickname': 'Klaus',
#     'waiverRank': 9},
#    'teamId': 10,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 47.3,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Jarvis',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '80',
#     'lastName': 'Landry',
#     'lastNewsDate': '2018-11-27T01:42:59.000Z',
#     'lastVideoDate': '2017-12-15T07:56:08.697Z',
#     'percentChange': -0.95353,
#     'percentOwned': 95.61528,
#     'percentStarted': 41.76262,
#     'playerId': 16790,
#     'proTeamId': 5,
#     'sportsId': 16790,
#     'tickerId': 2577303,
#     'universeId': 1,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/s/ffllm/logos/SmackTalk-LeoEspinosa/u_mad_bro-09.svg',
#     'teamAbbrev': 'QUIN',
#     'teamId': 8,
#     'teamLocation': 'Charlottesville',
#     'teamNickname': 'Challengers',
#     'waiverRank': 1},
#    'teamId': 8,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 1,
#     'draftRank': 116.8,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [0, 20],
#     'firstName': 'Matt',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '2',
#     'lastName': 'Ryan',
#     'lastNewsDate': '2018-11-23T07:07:04.000Z',
#     'lastVideoDate': '2017-12-28T18:07:14.677Z',
#     'percentChange': -0.23206,
#     'percentOwned': 95.55936,
#     'percentStarted': 55.91417,
#     'playerId': 11237,
#     'proTeamId': 1,
#     'sportsId': 11237,
#     'tickerId': 2125735,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://consequenceofsound.files.wordpress.com/2017/08/martin-shkreli.png?w=807',
#     'teamAbbrev': 'VETO',
#     'teamId': 2,
#     'teamLocation': 'Crooked Logans',
#     'teamNickname': 'Colluders',
#     'waiverRank': 7},
#    'teamId': 2,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 1,
#     'draftRank': 114.6,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [0, 20],
#     'firstName': 'Jared',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '16',
#     'lastName': 'Goff',
#     'lastNewsDate': '2018-11-20T05:10:03.000Z',
#     'lastVideoDate': '2017-12-24T21:46:53.413Z',
#     'percentChange': 0.52371,
#     'percentOwned': 95.1899,
#     'percentStarted': 57.83655,
#     'playerId': 17794,
#     'proTeamId': 14,
#     'sportsId': 3046779,
#     'tickerId': 3046779,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_beer.svg',
#     'teamAbbrev': 'ROB',
#     'teamId': 3,
#     'teamLocation': 'Team',
#     'teamNickname': 'Cavanaugh',
#     'waiverRank': 5},
#    'teamId': 3,
#    'watchList': False},
#   {'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'keeper': False,
#    'lockStatus': 3,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 74.8,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Tevin',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '26',
#     'lastName': 'Coleman',
#     'lastNewsDate': '2018-11-23T06:21:02.000Z',
#     'lastVideoDate': '2017-12-07T16:16:35.210Z',
#     'percentChange': -0.61423,
#     'percentOwned': 95.15375,
#     'percentStarted': 57.30834,
#     'playerId': 17689,
#     'proTeamId': 1,
#     'sportsId': 2979477,
#     'tickerId': 2979477,
#     'universeId': 2,
#     'value': -1},
#    'rosterStatus': 1,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'customValid',
#     'logoUrl': 'https://consequenceofsound.files.wordpress.com/2017/08/martin-shkreli.png?w=807',
#     'teamAbbrev': 'VETO',
#     'teamId': 2,
#     'teamLocation': 'Crooked Logans',
#     'teamNickname': 'Colluders',
#     'waiverRank': 7},
#    'teamId': 2,
#    'watchList': False}],
#  'progames': {'380906021': {'awayProTeamId': 1,
#    'awayScore': 12,
#    'gameDate': '2018-09-07T00:55:00.000Z',
#    'gameId': 380906021,
#    'homeProTeamId': 21,
#    'homeScore': 18,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909005': {'awayProTeamId': 23,
#    'awayScore': 21,
#    'gameDate': '2018-09-09T17:00:00.000Z',
#    'gameId': 380909005,
#    'homeProTeamId': 5,
#    'homeScore': 21,
#    'period': 5,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909007': {'awayProTeamId': 26,
#    'awayScore': 24,
#    'gameDate': '2018-09-09T20:25:00.000Z',
#    'gameId': 380909007,
#    'homeProTeamId': 7,
#    'homeScore': 27,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909009': {'awayProTeamId': 3,
#    'awayScore': 23,
#    'gameDate': '2018-09-10T00:20:00.000Z',
#    'gameId': 380909009,
#    'homeProTeamId': 9,
#    'homeScore': 24,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909011': {'awayProTeamId': 4,
#    'awayScore': 34,
#    'gameDate': '2018-09-09T17:00:00.000Z',
#    'gameId': 380909011,
#    'homeProTeamId': 11,
#    'homeScore': 23,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909016': {'awayProTeamId': 25,
#    'awayScore': 16,
#    'gameDate': '2018-09-09T17:00:00.000Z',
#    'gameId': 380909016,
#    'homeProTeamId': 16,
#    'homeScore': 24,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909017': {'awayProTeamId': 34,
#    'awayScore': 20,
#    'gameDate': '2018-09-09T17:00:00.000Z',
#    'gameId': 380909017,
#    'homeProTeamId': 17,
#    'homeScore': 27,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909018': {'awayProTeamId': 27,
#    'awayScore': 48,
#    'gameDate': '2018-09-09T17:00:00.000Z',
#    'gameId': 380909018,
#    'homeProTeamId': 18,
#    'homeScore': 40,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909019': {'awayProTeamId': 30,
#    'awayScore': 20,
#    'gameDate': '2018-09-09T17:00:00.000Z',
#    'gameId': 380909019,
#    'homeProTeamId': 19,
#    'homeScore': 15,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909022': {'awayProTeamId': 28,
#    'awayScore': 24,
#    'gameDate': '2018-09-09T20:25:00.000Z',
#    'gameId': 380909022,
#    'homeProTeamId': 22,
#    'homeScore': 6,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909024': {'awayProTeamId': 12,
#    'awayScore': 38,
#    'gameDate': '2018-09-09T20:05:00.000Z',
#    'gameId': 380909024,
#    'homeProTeamId': 24,
#    'homeScore': 28,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380909029': {'awayProTeamId': 6,
#    'awayScore': 8,
#    'gameDate': '2018-09-09T20:25:00.000Z',
#    'gameId': 380909029,
#    'homeProTeamId': 29,
#    'homeScore': 16,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'},
#   '380910013': {'awayProTeamId': 14,
#    'awayScore': 33,
#    'gameDate': '2018-09-11T02:20:00.000Z',
#    'gameId': 380910013,
#    'homeProTeamId': 13,
#    'homeScore': 13,
#    'period': 4,
#    'status': 3,
#    'timeRemainingInPeriod': '0:00'}},
#  'scoringPeriodId': 1}

# %%
score_boards = {}
box_scores = {}

for week in range(1,17):   
    score_board = requests.get('http://games.espn.com/ffl/api/v2/scoreboard', 
                               params={'leagueId': league_id, 'seasonId': season_id,
                                       'matchupPeriodId': week},
                               cookies={'swid': SWID, 'espn_s2': ESPN_S2}).json()
    score_boards[week] = score_board
    box_scores[week] = {}
    
    # loop through matchups that week
    for match in range(len(score_board['scoreboard']['matchups'])):
        home_id = score_board['scoreboard']['matchups'][match]['teams'][0]['team']['teamId']
        
        box_score = requests.get('http://games.espn.com/ffl/api/v2/boxscore', 
                                 params={'leagueId': league_id, 'seasonId': season_id,
                                         'teamId': home_id, 'matchupPeriodId': week},
                                 cookies={'swid': SWID, 'espn_s2': ESPN_S2}).json()
        # dont need meta data, can just use 'boxscore'
        box_scores[week][match] = box_score['boxscore']

# %%
len(score_boards[1]['scoreboard']['matchups'])
# Out:
# 5

# %%
score_boards[1]['scoreboard']['matchups'][0].keys()
# Out:
# dict_keys(['winner', 'teams', 'bye'])

# %%
score_boards[1]['scoreboard']['matchups'][0]
# Out:
# {'bye': False,
#  'teams': [{'home': True,
#    'playerIDs': [17683,
#     17929,
#     12514,
#     14881,
#     13232,
#     60030,
#     17668,
#     16040,
#     14993,
#     14922,
#     15966,
#     17810,
#     18395,
#     15920,
#     16804,
#     18168,
#     60003],
#    'score': 133.4,
#    'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/ffl/CoachGruden-ChipWass/gruden-15.svg',
#     'record': {'awayLosses': 3,
#      'awayPercentage': 0,
#      'awayTies': 0,
#      'awayWins': 2,
#      'divisionLosses': 4,
#      'divisionPercentage': 0.33333,
#      'divisionStanding': 5,
#      'divisionTies': 0,
#      'divisionWins': 2,
#      'homeLosses': 6,
#      'homePercentage': 0,
#      'homeTies': 0,
#      'homeWins': 1,
#      'overallLosses': 9,
#      'overallPercentage': 0.25,
#      'overallStanding': 9,
#      'overallTies': 0,
#      'overallWins': 3,
#      'pointsAgainst': 1593.5,
#      'pointsFor': 1445.9,
#      'streakLength': 1,
#      'streakType': 2},
#     'teamAbbrev': 'dumb',
#     'teamId': 5,
#     'teamLocation': 'Domestic',
#     'teamNickname': 'Violins',
#     'waiverRank': 2},
#    'teamId': 5},
#   {'home': False,
#    'playerIDs': [18187,
#     18260,
#     5528,
#     17556,
#     16790,
#     2330,
#     17195,
#     60014,
#     18178,
#     11439,
#     17827,
#     18425,
#     16760,
#     16781,
#     16795,
#     17619,
#     11122],
#    'score': 139.8,
#    'team': {'division': {'divisionId': 1, 'divisionName': 'West', 'size': 5},
#     'logoType': 'vector',
#     'logoUrl': 'http://g.espncdn.com/s/ffllm/logos/SmackTalk-LeoEspinosa/u_mad_bro-09.svg',
#     'record': {'awayLosses': 5,
#      'awayPercentage': 0,
#      'awayTies': 0,
#      'awayWins': 2,
#      'divisionLosses': 6,
#      'divisionPercentage': 0.14286,
#      'divisionStanding': 5,
#      'divisionTies': 0,
#      'divisionWins': 1,
#      'homeLosses': 4,
#      'homePercentage': 0,
#      'homeTies': 0,
#      'homeWins': 1,
#      'overallLosses': 9,
#      'overallPercentage': 0.25,
#      'overallStanding': 10,
#      'overallTies': 0,
#      'overallWins': 3,
#      'pointsAgainst': 1543.6,
#      'pointsFor': 1337.5,
#      'streakLength': 5,
#      'streakType': 2},
#     'teamAbbrev': 'QUIN',
#     'teamId': 8,
#     'teamLocation': 'Charlottesville',
#     'teamNickname': 'Challengers',
#     'waiverRank': 1},
#    'teamId': 8}],
#  'winner': 'away'}

# %%
# week 1 match 0
box_scores[1][0].keys()
# Out:
# dict_keys(['scheduleItems', 'teams', 'matchupPeriodId', 'scoringPeriodId', 'allScoringPeriodsInMatchupPeriod', 'progames', 'homeTeamBonus'])

# %%
box_scores[1][0]['scheduleItems']
# Out:
# [{'matchupPeriodId': 1,
#   'matchups': [{'awayTeam': {'division': {'divisionId': 1,
#       'divisionName': 'West',
#       'size': 5},
#      'logoType': 'vector',
#      'logoUrl': 'http://g.espncdn.com/s/ffllm/logos/SmackTalk-LeoEspinosa/u_mad_bro-09.svg',
#      'teamAbbrev': 'QUIN',
#      'teamId': 8,
#      'teamLocation': 'Charlottesville',
#      'teamNickname': 'Challengers',
#      'waiverRank': 1},
#     'awayTeamAdjustment': 0,
#     'awayTeamId': 8,
#     'awayTeamScores': [139.8],
#     'homeTeam': {'division': {'divisionId': 0,
#       'divisionName': 'East',
#       'size': 5},
#      'logoType': 'vector',
#      'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/ffl/CoachGruden-ChipWass/gruden-15.svg',
#      'teamAbbrev': 'dumb',
#      'teamId': 5,
#      'teamLocation': 'Domestic',
#      'teamNickname': 'Violins',
#      'waiverRank': 2},
#     'homeTeamAdjustment': 0,
#     'homeTeamBonus': 0,
#     'homeTeamId': 5,
#     'homeTeamScores': [133.4],
#     'isBye': False,
#     'matchupTypeId': 0,
#     'outcome': 2}]}]

# %%
len(box_scores[1][0]['teams'])
# Out:
# 2

# %%
box_scores[1][0]['teams'][0].keys()
# Out:
# dict_keys(['appliedActiveRealTotal', 'appliedInactiveRealTotal', 'slots', 'teamId', 'appliedActiveProjectedTotal', 'team', 'appliedInactiveProjectedTotal'])

# %%
box_scores[1][0]['teams'][0]
# Out:
# {'appliedActiveProjectedTotal': 111.6,
#  'appliedActiveRealTotal': 133.4,
#  'appliedInactiveProjectedTotal': 59.5,
#  'appliedInactiveRealTotal': 69.3,
#  'slots': [{'currentPeriodProjectedStats': {'appliedStatTotal': 16,
#     'appliedStats': {'19': 0.1,
#      '20': -1.2,
#      '24': 2.9,
#      '25': 0.9,
#      '26': 0,
#      '4': 5.8,
#      '63': 0,
#      '72': -0.6,
#      '8': 8},
#     'rawStats': {'0': 30.54477,
#      '1': 18.93006,
#      '10': 2,
#      '11': 3,
#      '12': 1,
#      '13': 2,
#      '14': 1,
#      '15': 0.16335,
#      '16': 0.10675,
#      '17': 0.13589,
#      '18': 0.01836,
#      '19': 0.06952,
#      '2': 11.61471,
#      '20': 0.5958,
#      '21': 0.61975,
#      '22': 217.84802,
#      '23': 5.75456,
#      '24': 28.70874,
#      '25': 0.15529,
#      '26': 0.00584,
#      '27': 5,
#      '28': 2,
#      '29': 1,
#      '3': 217.84802,
#      '30': 1,
#      '33': 1,
#      '35': 0.01112,
#      '36': 0.00778,
#      '37': 0.03594,
#      '38': 0.00123,
#      '39': 4.98887,
#      '4': 1.44477,
#      '40': 28.70874,
#      '5': 43,
#      '6': 21,
#      '62': 0.07536,
#      '63': 0.00235,
#      '64': 2.77354,
#      '65': 0.51046,
#      '66': 0.08816,
#      '68': 0.59862,
#      '69': 0.24502,
#      '7': 10,
#      '70': 0.04056,
#      '72': 0.28558,
#      '73': 0.88138,
#      '8': 8,
#      '9': 4}},
#    'currentPeriodRealStats': {'appliedStatTotal': 19.5,
#     'appliedStats': {'20': -4, '24': 0.5, '4': 12, '8': 11},
#     'rawStats': {'0': 33,
#      '1': 19,
#      '10': 2,
#      '11': 3,
#      '12': 1,
#      '13': 2,
#      '14': 1,
#      '15': 1,
#      '156': 1,
#      '16': 1,
#      '2': 14,
#      '20': 2,
#      '21': 0.57576,
#      '22': 298,
#      '23': 2,
#      '24': 5,
#      '27': 1,
#      '3': 298,
#      '39': 2.5,
#      '4': 3,
#      '40': 5,
#      '5': 59,
#      '6': 29,
#      '64': 6,
#      '65': 1,
#      '66': 1,
#      '68': 2,
#      '7': 14,
#      '73': 2,
#      '8': 11,
#      '9': 5}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 7,
#    'player': {'defaultPositionId': 1,
#     'draftRank': 56.2,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [0, 20],
#     'firstName': 'Russell',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '3',
#     'lastName': 'Wilson',
#     'lastNewsDate': '2018-11-25T21:17:22.000Z',
#     'lastVideoDate': '2018-02-22T19:27:21.323Z',
#     'percentChange': 1.38826,
#     'percentOwned': 90.22335,
#     'percentStarted': 53.85998,
#     'playerId': 14881,
#     'playerRatingSeason': 203.5,
#     'positionRank': 13,
#     'proTeamId': 26,
#     'sportsId': 14881,
#     'tickerId': 2268321,
#     'totalPoints': 203.5,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380909007],
#    'pvoRank': 14,
#    'slotCategoryId': 0,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 19.1,
#     'appliedStats': {'24': 8.3,
#      '25': 4.2,
#      '26': 0,
#      '42': 3.8,
#      '43': 1.2,
#      '44': 0,
#      '53': 2.1,
#      '63': 0,
#      '72': -0.4},
#     'rawStats': {'23': 17.9,
#      '24': 82.5,
#      '25': 0.7,
#      '26': 0.01205,
#      '27': 16,
#      '28': 8,
#      '29': 4,
#      '30': 3,
#      '31': 1,
#      '33': 3,
#      '34': 1,
#      '35': 0.03836,
#      '36': 0.02685,
#      '37': 0.29814,
#      '38': 0.01017,
#      '39': 4.60894,
#      '40': 82.52424,
#      '41': 4.2,
#      '42': 37.7,
#      '43': 0.2,
#      '44': 0.00458,
#      '45': 0.00496,
#      '46': 0.00324,
#      '47': 7,
#      '48': 3,
#      '49': 1,
#      '50': 1,
#      '53': 4.2,
#      '56': 0.04423,
#      '57': 0.00137,
#      '58': 5.7,
#      '60': 8.97619,
#      '61': 37.66888,
#      '62': 0.01662,
#      '63': 0.0018,
#      '66': 0.37064,
#      '67': 0.08686,
#      '68': 0.5,
#      '70': 0.17049,
#      '71': 0.04864,
#      '72': 0.21914,
#      '73': 0.21914}},
#    'currentPeriodRealStats': {'appliedStatTotal': 22.2,
#     'appliedStats': {'24': 10.8, '42': 3.9, '43': 6, '53': 1.5},
#     'rawStats': {'155': 1,
#      '23': 20,
#      '24': 108,
#      '27': 21,
#      '28': 10,
#      '29': 5,
#      '30': 4,
#      '31': 2,
#      '32': 1,
#      '33': 4,
#      '34': 2,
#      '37': 1,
#      '39': 5.4,
#      '40': 108,
#      '41': 3,
#      '42': 39,
#      '43': 1,
#      '47': 7,
#      '48': 3,
#      '49': 1,
#      '50': 1,
#      '53': 3,
#      '58': 5,
#      '60': 13,
#      '61': 39}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 13,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 1.4,
#     'droppable': False,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Todd',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '30',
#     'lastName': 'Gurley II',
#     'lastNewsDate': '2018-11-29T01:07:28.000Z',
#     'lastVideoDate': '2017-12-31T15:21:49.853Z',
#     'percentChange': 0.00437,
#     'percentOwned': 99.96916,
#     'percentStarted': 76.62026,
#     'playerId': 17683,
#     'playerRatingSeason': 275.9000244140625,
#     'positionRank': 1,
#     'proTeamId': 14,
#     'sportsId': 2977644,
#     'tickerId': 2977644,
#     'totalPoints': 275.9000244140625,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380910013],
#    'pvoRank': 24,
#    'slotCategoryId': 2,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 13.3,
#     'appliedStats': {'24': 6.6,
#      '25': 1.8,
#      '26': 0,
#      '42': 2.8,
#      '43': 0.5,
#      '44': 0,
#      '53': 1.8,
#      '63': 0,
#      '72': -0.2},
#     'rawStats': {'23': 14.86168,
#      '24': 65.58929,
#      '25': 0.29958,
#      '26': 0.00645,
#      '27': 13,
#      '28': 6,
#      '29': 3,
#      '30': 2,
#      '31': 1,
#      '33': 2,
#      '34': 1,
#      '35': 0.031,
#      '36': 0.0217,
#      '37': 0.18823,
#      '38': 0.00642,
#      '39': 4.41332,
#      '40': 65.58929,
#      '41': 3.67003,
#      '42': 27.78512,
#      '43': 0.08323,
#      '44': 0.00323,
#      '45': 0.00306,
#      '46': 0.002,
#      '47': 5,
#      '48': 2,
#      '49': 1,
#      '50': 1,
#      '53': 3.67003,
#      '56': 0.01953,
#      '57': 0.0006,
#      '58': 4.68812,
#      '60': 7.57082,
#      '61': 27.78512,
#      '62': 0.00968,
#      '63': 0.00064,
#      '66': 0.12981,
#      '67': 0.03206,
#      '68': 0.16187,
#      '70': 0.05971,
#      '71': 0.01795,
#      '72': 0.07766,
#      '73': 0.07766}},
#    'currentPeriodRealStats': {'appliedStatTotal': 2.6,
#     'appliedStats': {'24': 2.2, '42': -0.1, '53': 0.5},
#     'rawStats': {'156': 1,
#      '23': 7,
#      '24': 22,
#      '27': 4,
#      '28': 2,
#      '29': 1,
#      '33': 1,
#      '39': 3.14286,
#      '40': 22,
#      '41': 1,
#      '42': -1,
#      '53': 1,
#      '58': 3,
#      '60': -1,
#      '61': -1}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 33,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 26.4,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'LeSean',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '25',
#     'lastName': 'McCoy',
#     'lastNewsDate': '2018-11-26T00:24:30.000Z',
#     'lastVideoDate': '2017-12-12T08:07:21.100Z',
#     'percentChange': -0.60704,
#     'percentOwned': 91.73901,
#     'percentStarted': 38.88216,
#     'playerId': 12514,
#     'playerRatingSeason': 86.9000015258789,
#     'positionRank': 37,
#     'proTeamId': 2,
#     'sportsId': 12514,
#     'tickerId': 2268582,
#     'totalPoints': 86.9000015258789,
#     'universeId': 1,
#     'value': -1},
#    'proGameIds': [380909033],
#    'pvoRank': 2,
#    'slotCategoryId': 2,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 12,
#     'appliedStats': {'102': 0.2,
#      '24': 0.7,
#      '25': 0.2,
#      '26': 0,
#      '42': 6.6,
#      '43': 1.7,
#      '44': 0,
#      '53': 2.6,
#      '63': 0,
#      '72': 0},
#     'rawStats': {'102': 0.03452,
#      '115': 16.96927,
#      '23': 1.06388,
#      '24': 7.43274,
#      '25': 0.02956,
#      '26': 0.00072,
#      '27': 1,
#      '35': 0.00197,
#      '36': 0.00138,
#      '37': 0.00237,
#      '38': 8e-05,
#      '39': 6.98643,
#      '40': 7.43274,
#      '41': 5.18775,
#      '42': 65.67083,
#      '43': 0.28114,
#      '44': 0.0105,
#      '45': 0.01469,
#      '46': 0.0096,
#      '47': 13,
#      '48': 6,
#      '49': 3,
#      '50': 2,
#      '51': 1,
#      '53': 5.18775,
#      '54': 1,
#      '56': 0.1941,
#      '57': 0.006,
#      '58': 7.62591,
#      '60': 12.65883,
#      '61': 65.67083,
#      '62': 0.01122,
#      '63': 0.00017,
#      '66': 0.00724,
#      '67': 0.03531,
#      '68': 0.04255,
#      '70': 0.00333,
#      '71': 0.01977,
#      '72': 0.0231,
#      '73': 0.0231}},
#    'currentPeriodRealStats': {'appliedStatTotal': 38.8,
#     'appliedStats': {'102': 6, '24': 0.4, '42': 16.9, '43': 12, '53': 3.5},
#     'rawStats': {'102': 1,
#      '105': 1,
#      '115': 95,
#      '118': 9,
#      '119': 3,
#      '155': 1,
#      '23': 2,
#      '24': 4,
#      '39': 2,
#      '40': 4,
#      '41': 7,
#      '42': 169,
#      '43': 2,
#      '45': 1,
#      '46': 1,
#      '47': 33,
#      '48': 16,
#      '49': 8,
#      '50': 6,
#      '51': 3,
#      '52': 1,
#      '53': 7,
#      '54': 1,
#      '56': 1,
#      '58': 8,
#      '60': 24.14286,
#      '61': 169}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 24,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 29.5,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Tyreek',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '10',
#     'lastName': 'Hill',
#     'lastNewsDate': '2018-11-20T06:18:02.000Z',
#     'lastVideoDate': '2017-12-16T15:57:25.857Z',
#     'percentChange': 0.00216,
#     'percentOwned': 99.8832,
#     'percentStarted': 76.22839,
#     'playerId': 17929,
#     'playerRatingSeason': 223.1999969482422,
#     'positionRank': 1,
#     'proTeamId': 12,
#     'sportsId': 3116406,
#     'tickerId': 3116406,
#     'totalPoints': 223.1999969482422,
#     'universeId': 1,
#     'value': -1},
#    'proGameIds': [380909024],
#    'pvoRank': 9,
#    'slotCategoryId': 4,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 10.1,
#     'appliedStats': {'24': 0.3,
#      '25': 0.1,
#      '26': 0,
#      '42': 5.4,
#      '43': 2,
#      '44': 0,
#      '53': 2.3,
#      '63': 0,
#      '72': -0.1},
#     'rawStats': {'23': 0.52004,
#      '24': 3.1755,
#      '25': 0.01222,
#      '26': 0.00068,
#      '35': 0.00096,
#      '36': 0.00067,
#      '37': 0.00042,
#      '38': 1e-05,
#      '39': 6.1063,
#      '40': 3.1755,
#      '41': 4.63919,
#      '42': 53.98948,
#      '43': 0.33788,
#      '44': 0.01983,
#      '45': 0.00749,
#      '46': 0.0049,
#      '47': 10,
#      '48': 5,
#      '49': 2,
#      '50': 2,
#      '51': 1,
#      '53': 4.63919,
#      '56': 0.11823,
#      '57': 0.00366,
#      '58': 7.38095,
#      '60': 11.63771,
#      '61': 53.98948,
#      '62': 0.02051,
#      '63': 0.00019,
#      '66': 0.00486,
#      '67': 0.04335,
#      '68': 0.04821,
#      '70': 0.00224,
#      '71': 0.02428,
#      '72': 0.02651,
#      '73': 0.02651}},
#    'currentPeriodRealStats': {'appliedStatTotal': 8.9,
#     'appliedStats': {'24': 1.6, '42': 3.3, '53': 4},
#     'rawStats': {'0': 1,
#      '1': 1,
#      '155': 1,
#      '21': 1,
#      '22': 15,
#      '23': 1,
#      '24': 16,
#      '27': 3,
#      '28': 1,
#      '3': 15,
#      '39': 16,
#      '40': 16,
#      '41': 8,
#      '42': 33,
#      '47': 6,
#      '48': 3,
#      '49': 1,
#      '5': 3,
#      '50': 1,
#      '53': 8,
#      '54': 1,
#      '58': 10,
#      '6': 1,
#      '60': 4.125,
#      '61': 33}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 1,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 107.8,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Nelson',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '13',
#     'lastName': 'Agholor',
#     'lastNewsDate': '2018-11-27T08:50:05.000Z',
#     'lastVideoDate': '2017-10-28T06:35:17.427Z',
#     'percentChange': -4.35833,
#     'percentOwned': 41.26729,
#     'percentStarted': 4.76988,
#     'playerId': 17668,
#     'playerRatingSeason': 79.4000015258789,
#     'positionRank': 57,
#     'proTeamId': 21,
#     'sportsId': 2971618,
#     'tickerId': 2971618,
#     'totalPoints': 79.4000015258789,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380906021],
#    'pvoRank': 25,
#    'slotCategoryId': 4,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 8.2,
#     'appliedStats': {'42': 3.8,
#      '43': 2.7,
#      '44': 0,
#      '53': 1.7,
#      '63': 0,
#      '72': 0},
#     'rawStats': {'41': 3.36922,
#      '42': 38.3697,
#      '43': 0.45081,
#      '44': 0.01668,
#      '45': 0.00799,
#      '46': 0.00522,
#      '47': 7,
#      '48': 3,
#      '49': 1,
#      '50': 1,
#      '53': 3.36922,
#      '56': 0.04654,
#      '57': 0.00144,
#      '58': 5.16724,
#      '60': 11.3883,
#      '61': 38.3697,
#      '62': 0.01668,
#      '63': 0.00012,
#      '67': 0.03146,
#      '68': 0.03146,
#      '71': 0.01762,
#      '72': 0.01762,
#      '73': 0.01762}},
#    'currentPeriodRealStats': {'appliedStatTotal': 1.8,
#     'appliedStats': {'42': 0.8, '53': 1},
#     'rawStats': {'155': 1,
#      '41': 2,
#      '42': 8,
#      '47': 1,
#      '53': 2,
#      '58': 4,
#      '60': 4,
#      '61': 8}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 3,
#    'player': {'defaultPositionId': 4,
#     'draftRank': 59,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [6, 23, 20],
#     'firstName': 'Jimmy',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '80',
#     'lastName': 'Graham',
#     'lastNewsDate': '2018-11-29T21:50:04.000Z',
#     'lastVideoDate': '2017-12-24T08:57:37.117Z',
#     'percentChange': -2.28968,
#     'percentOwned': 87.52841,
#     'percentStarted': 28.46241,
#     'playerId': 13232,
#     'playerRatingSeason': 78.5999984741211,
#     'positionRank': 11,
#     'proTeamId': 9,
#     'sportsId': 13232,
#     'tickerId': 2466958,
#     'totalPoints': 78.5999984741211,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380909009],
#    'pvoRank': 10,
#    'slotCategoryId': 6,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 8.4,
#     'appliedStats': {'24': 0.1,
#      '25': 0,
#      '26': 0,
#      '42': 4.5,
#      '43': 1.6,
#      '44': 0,
#      '53': 2.1,
#      '63': 0,
#      '72': 0},
#     'rawStats': {'23': 0.23466,
#      '24': 1.31214,
#      '25': 0.00666,
#      '26': 0.00017,
#      '35': 0.00043,
#      '36': 0.0003,
#      '37': 7e-05,
#      '38': 0,
#      '39': 5.5917,
#      '40': 1.31214,
#      '41': 4.18077,
#      '42': 45.38026,
#      '43': 0.27293,
#      '44': 0.00872,
#      '45': 0.00736,
#      '46': 0.00481,
#      '47': 9,
#      '48': 4,
#      '49': 2,
#      '50': 1,
#      '53': 4.18077,
#      '56': 0.074,
#      '57': 0.00229,
#      '58': 6.22911,
#      '60': 10.85452,
#      '61': 45.38026,
#      '62': 0.0089,
#      '63': 0.00014,
#      '66': 0.00189,
#      '67': 0.03364,
#      '68': 0.03553,
#      '70': 0.00087,
#      '71': 0.01884,
#      '72': 0.01971,
#      '73': 0.01971}},
#    'currentPeriodRealStats': {'appliedStatTotal': 3.8,
#     'appliedStats': {'42': 1.8, '53': 2},
#     'rawStats': {'156': 1,
#      '41': 4,
#      '42': 18,
#      '47': 3,
#      '48': 1,
#      '53': 4,
#      '58': 7,
#      '60': 4.5,
#      '61': 18}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 21,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 126.6,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Mohamed',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '12',
#     'lastName': 'Sanu',
#     'lastNewsDate': '2018-11-23T08:07:31.000Z',
#     'lastVideoDate': '2017-12-18T14:18:36.713Z',
#     'percentChange': 0.14425,
#     'percentOwned': 53.71197,
#     'percentStarted': 16.20714,
#     'playerId': 14922,
#     'playerRatingSeason': 93.80000305175781,
#     'positionRank': 42,
#     'proTeamId': 1,
#     'sportsId': 14922,
#     'tickerId': 2468948,
#     'totalPoints': 93.80000305175781,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380906021],
#    'pvoRank': 31,
#    'slotCategoryId': 23,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 8.1,
#     'appliedStats': {'24': 0.3,
#      '25': 0.1,
#      '26': 0,
#      '42': 4.5,
#      '43': 1.6,
#      '44': 0,
#      '53': 1.6,
#      '63': 0,
#      '72': 0},
#     'rawStats': {'23': 0.46533,
#      '24': 2.93156,
#      '25': 0.00999,
#      '26': 0.00022,
#      '35': 0.00086,
#      '36': 0.0006,
#      '37': 0.00036,
#      '38': 1e-05,
#      '39': 6.3,
#      '40': 2.93156,
#      '41': 3.24419,
#      '42': 44.80024,
#      '43': 0.27341,
#      '44': 0.00612,
#      '45': 0.01235,
#      '46': 0.00807,
#      '47': 8,
#      '48': 4,
#      '49': 2,
#      '50': 1,
#      '53': 3.24419,
#      '56': 0.07143,
#      '57': 0.00221,
#      '58': 5.43413,
#      '60': 13.80939,
#      '61': 44.80024,
#      '62': 0.00634,
#      '63': 0.00015,
#      '66': 0.00487,
#      '67': 0.03397,
#      '68': 0.03884,
#      '70': 0.00224,
#      '71': 0.01902,
#      '72': 0.02126,
#      '73': 0.02126}},
#    'currentPeriodRealStats': {'appliedStatTotal': 6.8,
#     'appliedStats': {'42': 0.3, '43': 6, '53': 0.5},
#     'rawStats': {'155': 1,
#      '41': 1,
#      '42': 3,
#      '43': 1,
#      '53': 1,
#      '58': 2,
#      '60': 3,
#      '61': 3}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 11,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 131.8,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'John',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '15',
#     'lastName': 'Ross',
#     'lastNewsDate': '2018-11-25T22:53:50.000Z',
#     'lastVideoDate': '2017-08-14T15:51:01.550Z',
#     'percentChange': 2.51472,
#     'percentOwned': 17.5432,
#     'percentStarted': 3.12933,
#     'playerId': 18395,
#     'playerRatingSeason': 54.29999923706055,
#     'positionRank': 78,
#     'proTeamId': 4,
#     'sportsId': 3052177,
#     'tickerId': 3052177,
#     'totalPoints': 54.29999923706055,
#     'universeId': 1,
#     'value': -1},
#    'proGameIds': [380909011],
#    'pvoRank': 8,
#    'slotCategoryId': 23,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 7.2,
#     'appliedStats': {'101': 0,
#      '102': 0.2,
#      '103': 0.7,
#      '104': 0.5,
#      '93': 0,
#      '95': 2.2,
#      '96': 1.2,
#      '97': 0.2,
#      '98': 0,
#      '99': 2.1},
#     'rawStats': {'100': 4,
#      '101': 0.00649,
#      '102': 0.03899,
#      '103': 0.1146,
#      '104': 0.08863,
#      '105': 0.25657,
#      '106': 0.91311,
#      '112': 4.09934,
#      '113': 5.07021,
#      '114': 48.84073,
#      '115': 20.27351,
#      '120': 20.05468,
#      '121': 1,
#      '126': 20.05468,
#      '127': 336.8483,
#      '131': 1,
#      '137': 336.8483,
#      '160': -20.05468,
#      '93': 0.00785,
#      '94': 0.20323,
#      '95': 1.09639,
#      '96': 0.59352,
#      '97': 0.08213,
#      '98': 0.02394,
#      '99': 2.11861}},
#    'currentPeriodRealStats': {'appliedStatTotal': 13,
#     'appliedStats': {'103': 6, '92': 1, '95': 2, '96': 2, '99': 2},
#     'rawStats': {'100': 4,
#      '103': 1,
#      '105': 1,
#      '107': 22,
#      '108': 46,
#      '109': 68,
#      '110': 22,
#      '111': 13,
#      '112': 7,
#      '113': 5,
#      '114': 45,
#      '115': 10,
#      '116': 4,
#      '117': 1,
#      '118': 1,
#      '120': 15,
#      '126': 15,
#      '127': 324,
#      '131': 1,
#      '137': 324,
#      '92': 1,
#      '94': 1,
#      '95': 1,
#      '96': 1,
#      '99': 2}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 19,
#    'player': {'defaultPositionId': 16,
#     'draftRank': 66.6,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [16, 20],
#     'firstName': 'Jaguars',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'lastName': 'D/ST',
#     'lastNewsDate': '1970-01-01T00:00:00.000Z',
#     'lastVideoDate': '2017-12-21T14:19:19.127Z',
#     'percentChange': -11.68493,
#     'percentOwned': 71.37149,
#     'percentStarted': 35.64405,
#     'playerId': 60030,
#     'playerRatingSeason': 55,
#     'positionRank': 19,
#     'proTeamId': 30,
#     'sportsId': 60030,
#     'tickerId': 0,
#     'totalPoints': 55,
#     'universeId': 1,
#     'value': -1},
#    'proGameIds': [380909019],
#    'pvoRank': 22,
#    'slotCategoryId': 16,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 9.1,
#     'appliedStats': {'74': 1.1, '77': 2.2, '80': 3.5, '85': -0.3, '86': 2.6},
#     'rawStats': {'74': 0.22346,
#      '75': 0.34716,
#      '76': 0.1237,
#      '77': 0.55861,
#      '78': 0.69593,
#      '79': 0.13732,
#      '80': 1.18078,
#      '81': 1.24992,
#      '82': 0.06914,
#      '83': 1.96285,
#      '84': 2.29301,
#      '85': 0.33016,
#      '86': 2.57504,
#      '87': 2.71148,
#      '88': 0.13644}},
#    'currentPeriodRealStats': {'appliedStatTotal': 16,
#     'appliedStats': {'74': 5, '80': 9, '85': -1, '86': 3},
#     'rawStats': {'155': 1,
#      '74': 1,
#      '75': 1,
#      '78': 1,
#      '79': 1,
#      '80': 3,
#      '81': 3,
#      '83': 4,
#      '84': 5,
#      '85': 1,
#      '86': 3,
#      '87': 3}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 13,
#    'player': {'defaultPositionId': 5,
#     'draftRank': 99.3,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [17, 20],
#     'firstName': 'Greg',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '4',
#     'lastName': 'Zuerlein',
#     'lastNewsDate': '2018-11-20T16:01:10.000Z',
#     'lastVideoDate': '2017-12-23T15:43:51.263Z',
#     'percentChange': 1.36102,
#     'percentOwned': 92.8554,
#     'percentStarted': 69.80575,
#     'playerId': 14993,
#     'playerRatingSeason': 71,
#     'positionRank': 24,
#     'proTeamId': 14,
#     'sportsId': 14993,
#     'tickerId': 2242559,
#     'totalPoints': 71,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380910013],
#    'pvoRank': 26,
#    'slotCategoryId': 17,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 6.3,
#     'appliedStats': {'24': 3.5,
#      '25': 1.5,
#      '26': 0,
#      '42': 0.8,
#      '43': 0.2,
#      '44': 0,
#      '53': 0.5,
#      '63': 0,
#      '72': -0.1},
#     'rawStats': {'23': 8.25926,
#      '24': 34.61329,
#      '25': 0.24634,
#      '26': 0.00649,
#      '27': 6,
#      '28': 3,
#      '29': 1,
#      '30': 1,
#      '33': 1,
#      '35': 0.0163,
#      '36': 0.01141,
#      '37': 0.0523,
#      '38': 0.00178,
#      '39': 4.19085,
#      '40': 34.61329,
#      '41': 0.92507,
#      '42': 7.53953,
#      '43': 0.02679,
#      '44': 0.00133,
#      '45': 0.00347,
#      '46': 0.00226,
#      '47': 1,
#      '53': 0.92507,
#      '56': 0.00305,
#      '57': 9e-05,
#      '58': 1.23244,
#      '60': 8.15025,
#      '61': 7.53953,
#      '62': 0.00782,
#      '63': 0.00025,
#      '66': 0.05615,
#      '67': 0.00629,
#      '68': 0.06244,
#      '70': 0.02583,
#      '71': 0.00352,
#      '72': 0.02935,
#      '73': 0.02935}},
#    'currentPeriodRealStats': {'appliedStatTotal': 3.5,
#     'appliedStats': {'24': 3.5},
#     'rawStats': {'155': 1,
#      '23': 7,
#      '24': 35,
#      '27': 7,
#      '28': 3,
#      '29': 1,
#      '30': 1,
#      '33': 1,
#      '39': 5,
#      '40': 35}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 6,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 170,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'C.J.',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'lastName': 'Anderson',
#     'lastNewsDate': '2018-11-27T22:39:37.000Z',
#     'lastVideoDate': '2017-12-31T13:41:28.710Z',
#     'percentChange': -0.62068,
#     'percentOwned': 2.93862,
#     'percentStarted': 0.10607,
#     'playerId': 16040,
#     'playerRatingSeason': 19.299999237060547,
#     'positionRank': 78,
#     'proTeamId': 29,
#     'sportsId': 16040,
#     'tickerId': 2576853,
#     'totalPoints': 19.299999237060547,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380909029],
#    'pvoRank': 7,
#    'slotCategoryId': 20,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 8.1,
#     'appliedStats': {'24': 2.2,
#      '25': 0.9,
#      '26': 0,
#      '42': 2.8,
#      '43': 0.7,
#      '44': 0,
#      '53': 1.6,
#      '63': 0,
#      '72': -0.1},
#     'rawStats': {'23': 4.96193,
#      '24': 21.60595,
#      '25': 0.14279,
#      '26': 0.0029,
#      '27': 4,
#      '28': 2,
#      '29': 1,
#      '35': 0.00952,
#      '36': 0.00666,
#      '37': 0.02032,
#      '38': 0.00069,
#      '39': 4.35434,
#      '40': 21.60595,
#      '41': 3.23394,
#      '42': 28.22477,
#      '43': 0.12153,
#      '44': 0.0033,
#      '45': 0.00525,
#      '46': 0.00343,
#      '47': 5,
#      '48': 2,
#      '49': 1,
#      '50': 1,
#      '53': 3.23394,
#      '56': 0.02033,
#      '57': 0.00063,
#      '58': 4.18766,
#      '60': 8.72768,
#      '61': 28.22477,
#      '62': 0.0062,
#      '63': 0.00047,
#      '66': 0.07165,
#      '67': 0.0467,
#      '68': 0.11834,
#      '70': 0.03296,
#      '71': 0.02615,
#      '72': 0.05911,
#      '73': 0.05911}},
#    'currentPeriodRealStats': {'appliedStatTotal': 21.8,
#     'appliedStats': {'24': 6.5, '42': 6.3, '43': 6, '53': 3},
#     'rawStats': {'155': 1,
#      '23': 5,
#      '24': 65,
#      '27': 13,
#      '28': 6,
#      '29': 3,
#      '30': 2,
#      '31': 1,
#      '33': 1,
#      '39': 13,
#      '40': 65,
#      '41': 6,
#      '42': 63,
#      '43': 1,
#      '47': 12,
#      '48': 6,
#      '49': 3,
#      '50': 2,
#      '51': 1,
#      '53': 6,
#      '54': 1,
#      '58': 7,
#      '60': 10.5,
#      '61': 63}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 22,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 77.9,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Chris',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '25',
#     'lastName': 'Thompson',
#     'lastNewsDate': '2018-11-26T22:46:45.000Z',
#     'lastVideoDate': '2017-11-15T06:01:04.420Z',
#     'percentChange': -0.23037,
#     'percentOwned': 53.02836,
#     'percentStarted': 2.34565,
#     'playerId': 15966,
#     'playerRatingSeason': 52.20000076293945,
#     'positionRank': 56,
#     'proTeamId': 28,
#     'sportsId': 15966,
#     'tickerId': 2466030,
#     'totalPoints': 52.20000076293945,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380909022],
#    'pvoRank': 30,
#    'slotCategoryId': 20,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 8.6,
#     'appliedStats': {'42': 4.7,
#      '43': 2.3,
#      '44': 0,
#      '53': 1.6,
#      '63': 0,
#      '72': 0},
#     'rawStats': {'41': 3.23788,
#      '42': 46.548,
#      '43': 0.39041,
#      '44': 0.01061,
#      '45': 0.01109,
#      '46': 0.00725,
#      '47': 9,
#      '48': 4,
#      '49': 2,
#      '50': 1,
#      '53': 3.23788,
#      '56': 0.07933,
#      '57': 0.00245,
#      '58': 5.7983,
#      '60': 14.37606,
#      '61': 46.548,
#      '62': 0.01061,
#      '63': 0.00013,
#      '67': 0.0339,
#      '68': 0.0339,
#      '71': 0.01898,
#      '72': 0.01898,
#      '73': 0.01898}},
#    'currentPeriodRealStats': {'appliedStatTotal': 1.6,
#     'appliedStats': {'42': 1.1, '53': 0.5},
#     'rawStats': {'155': 1,
#      '41': 1,
#      '42': 11,
#      '47': 2,
#      '48': 1,
#      '53': 1,
#      '58': 3,
#      '60': 11,
#      '61': 11}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 22,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 114.4,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'Josh',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '18',
#     'lastName': 'Doctson',
#     'lastNewsDate': '2018-11-26T18:00:20.000Z',
#     'lastVideoDate': '2017-12-03T07:09:07.370Z',
#     'percentChange': -0.44964,
#     'percentOwned': 15.66048,
#     'percentStarted': 2.58475,
#     'playerId': 17810,
#     'playerRatingSeason': 61.400001525878906,
#     'positionRank': 72,
#     'proTeamId': 28,
#     'sportsId': 2576019,
#     'tickerId': 2576019,
#     'totalPoints': 61.400001525878906,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380909022],
#    'pvoRank': 12,
#    'slotCategoryId': 20,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 8.1,
#     'appliedStats': {'24': 3.7,
#      '25': 2.1,
#      '26': 0,
#      '42': 1.3,
#      '43': 0.3,
#      '44': 0,
#      '53': 0.8,
#      '63': 0,
#      '72': -0.1},
#     'rawStats': {'23': 9.40411,
#      '24': 36.74793,
#      '25': 0.34886,
#      '26': 0.00967,
#      '27': 7,
#      '28': 3,
#      '29': 1,
#      '30': 1,
#      '33': 1,
#      '35': 0.01875,
#      '36': 0.01312,
#      '37': 0.05897,
#      '38': 0.00201,
#      '39': 3.90765,
#      '40': 36.74793,
#      '41': 1.66883,
#      '42': 12.9554,
#      '43': 0.04389,
#      '44': 0.00156,
#      '45': 0.00356,
#      '46': 0.00233,
#      '47': 2,
#      '48': 1,
#      '53': 1.66883,
#      '56': 0.00484,
#      '57': 0.00015,
#      '58': 2.10388,
#      '60': 7.76314,
#      '61': 12.9554,
#      '62': 0.01122,
#      '63': 0.00035,
#      '66': 0.07643,
#      '67': 0.01356,
#      '68': 0.08999,
#      '70': 0.03516,
#      '71': 0.00759,
#      '72': 0.04275,
#      '73': 0.04275}},
#    'currentPeriodRealStats': {'appliedStatTotal': 4.2,
#     'appliedStats': {'24': 4.2},
#     'rawStats': {'155': 1,
#      '23': 11,
#      '24': 42,
#      '27': 8,
#      '28': 4,
#      '29': 2,
#      '30': 1,
#      '33': 2,
#      '34': 1,
#      '39': 3.81818,
#      '40': 42}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 25,
#    'player': {'defaultPositionId': 2,
#     'draftRank': 128.6,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [2, 23, 20],
#     'firstName': 'Latavius',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '25',
#     'lastName': 'Murray',
#     'lastNewsDate': '2018-11-26T08:30:44.000Z',
#     'lastVideoDate': '2017-12-23T18:16:16.800Z',
#     'percentChange': -7.56014,
#     'percentOwned': 56.61382,
#     'percentStarted': 3.38558,
#     'playerId': 15920,
#     'playerRatingSeason': 99.69999694824219,
#     'positionRank': 28,
#     'proTeamId': 16,
#     'sportsId': 15920,
#     'tickerId': 2312251,
#     'totalPoints': 99.69999694824219,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380909016],
#    'pvoRank': 17,
#    'slotCategoryId': 20,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 6.3,
#     'appliedStats': {'24': 0.1,
#      '25': 0,
#      '26': 0,
#      '42': 3.8,
#      '43': 1.1,
#      '44': 0,
#      '53': 1.3,
#      '63': 0,
#      '72': 0},
#     'rawStats': {'23': 0.14621,
#      '24': 0.93577,
#      '25': 0.00345,
#      '26': 9e-05,
#      '35': 0.00027,
#      '36': 0.00019,
#      '37': 3e-05,
#      '38': 0,
#      '39': 6.4,
#      '40': 0.93577,
#      '41': 2.69769,
#      '42': 37.61065,
#      '43': 0.17977,
#      '44': 0.0088,
#      '45': 0.00789,
#      '46': 0.00515,
#      '47': 7,
#      '48': 3,
#      '49': 1,
#      '50': 1,
#      '53': 2.69769,
#      '56': 0.04404,
#      '57': 0.00136,
#      '58': 5.08092,
#      '60': 13.94178,
#      '61': 37.61065,
#      '62': 0.00889,
#      '63': 0.0001,
#      '66': 0.0013,
#      '67': 0.02396,
#      '68': 0.02526,
#      '70': 0.0006,
#      '71': 0.01342,
#      '72': 0.01402,
#      '73': 0.01402}},
#    'currentPeriodRealStats': {'appliedStatTotal': 12,
#     'appliedStats': {'24': 0.1, '42': 4.4, '43': 6, '53': 1.5},
#     'rawStats': {'155': 1,
#      '23': 1,
#      '24': 1,
#      '39': 1,
#      '40': 1,
#      '41': 3,
#      '42': 44,
#      '43': 1,
#      '47': 8,
#      '48': 4,
#      '49': 2,
#      '50': 1,
#      '53': 3,
#      '58': 4,
#      '60': 14.66667,
#      '61': 44}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 2,
#    'player': {'defaultPositionId': 3,
#     'draftRank': 138.4,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [4, 23, 20],
#     'firstName': 'John',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '13',
#     'lastName': 'Brown',
#     'lastNewsDate': '2018-11-25T23:30:07.000Z',
#     'lastVideoDate': '2017-10-07T06:54:41.267Z',
#     'percentChange': -6.72294,
#     'percentOwned': 56.08379,
#     'percentStarted': 6.35944,
#     'playerId': 16804,
#     'playerRatingSeason': 107.30000305175781,
#     'positionRank': 28,
#     'proTeamId': 33,
#     'sportsId': 16804,
#     'tickerId': 2318712,
#     'totalPoints': 107.30000305175781,
#     'universeId': 1,
#     'value': -1},
#    'proGameIds': [380909033],
#    'pvoRank': 1,
#    'slotCategoryId': 20,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 16.5,
#     'appliedStats': {'19': 0.1,
#      '20': -1.6,
#      '24': 1.7,
#      '25': 0.9,
#      '26': 0,
#      '4': 6.2,
#      '63': 0,
#      '72': -0.8,
#      '8': 10},
#     'rawStats': {'0': 36.3451,
#      '1': 22.23322,
#      '10': 2,
#      '11': 4,
#      '12': 2,
#      '13': 2,
#      '14': 1,
#      '15': 0.23572,
#      '16': 0.15404,
#      '17': 0.28237,
#      '18': 0.03814,
#      '19': 0.0554,
#      '2': 14.11188,
#      '20': 0.77544,
#      '21': 0.61173,
#      '22': 265.74575,
#      '23': 3.91369,
#      '24': 16.69797,
#      '25': 0.14262,
#      '26': 0.00418,
#      '27': 3,
#      '28': 1,
#      '3': 265.74575,
#      '35': 0.00744,
#      '36': 0.00521,
#      '37': 0.01211,
#      '38': 0.00041,
#      '39': 4.26655,
#      '4': 1.5469,
#      '40': 16.69797,
#      '5': 53,
#      '6': 26,
#      '62': 0.05958,
#      '63': 0.00322,
#      '64': 2.91701,
#      '65': 0.74525,
#      '66': 0.07429,
#      '68': 0.81953,
#      '69': 0.35772,
#      '7': 13,
#      '70': 0.03417,
#      '72': 0.39189,
#      '73': 1.16733,
#      '8': 10,
#      '9': 5}},
#    'currentPeriodRealStats': {'appliedStatTotal': 13.2,
#     'appliedStats': {'24': 3.2, '25': 6, '72': -2, '8': 6},
#     'rawStats': {'0': 35,
#      '1': 23,
#      '10': 1,
#      '11': 4,
#      '12': 2,
#      '13': 2,
#      '14': 1,
#      '156': 1,
#      '2': 12,
#      '21': 0.65714,
#      '22': 171,
#      '23': 7,
#      '24': 32,
#      '25': 1,
#      '27': 6,
#      '28': 3,
#      '29': 1,
#      '3': 171,
#      '30': 1,
#      '33': 1,
#      '39': 4.57143,
#      '40': 32,
#      '5': 34,
#      '6': 17,
#      '64': 4,
#      '65': 2,
#      '68': 2,
#      '69': 1,
#      '7': 8,
#      '72': 1,
#      '73': 1,
#      '8': 6,
#      '9': 3}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 9,
#    'player': {'defaultPositionId': 1,
#     'draftRank': 108.1,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [0, 20],
#     'firstName': 'Mitchell',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 2,
#     'isActive': True,
#     'isIREligible': False,
#     'jersey': '10',
#     'lastName': 'Trubisky',
#     'lastNewsDate': '2018-11-29T22:28:25.000Z',
#     'lastVideoDate': '2018-03-18T05:13:49.213Z',
#     'percentChange': -2.45815,
#     'percentOwned': 75.24672,
#     'percentStarted': 11.67154,
#     'playerId': 18168,
#     'playerRatingSeason': 212.3000030517578,
#     'positionRank': 11,
#     'proTeamId': 3,
#     'sportsId': 3039707,
#     'tickerId': 3039707,
#     'totalPoints': 212.3000030517578,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380909009],
#    'pvoRank': 15,
#    'slotCategoryId': 20,
#    'watchList': False},
#   {'currentPeriodProjectedStats': {'appliedStatTotal': 5.6,
#     'appliedStats': {'101': 0,
#      '102': 0.2,
#      '103': 0.2,
#      '104': 0.4,
#      '93': 0,
#      '95': 0.8,
#      '96': 0.9,
#      '97': 0.2,
#      '98': 0,
#      '99': 2.8},
#     'rawStats': {'100': 5,
#      '101': 0.00803,
#      '102': 0.03975,
#      '103': 0.0398,
#      '104': 0.06074,
#      '105': 0.15655,
#      '106': 0.68103,
#      '112': 2.97013,
#      '113': 4.42002,
#      '114': 46.23908,
#      '115': 18.60719,
#      '120': 24.46172,
#      '122': 1,
#      '126': 24.46172,
#      '127': 338.82487,
#      '131': 1,
#      '137': 338.82487,
#      '160': -24.46172,
#      '93': 0.00819,
#      '94': 0.10054,
#      '95': 0.39019,
#      '96': 0.44267,
#      '97': 0.09516,
#      '98': 0.02277,
#      '99': 2.78255}},
#    'currentPeriodRealStats': {'appliedStatTotal': 13,
#     'appliedStats': {'103': 6, '132': -1, '95': 2, '96': 2, '99': 4},
#     'rawStats': {'100': 8,
#      '103': 1,
#      '105': 1,
#      '106': 2,
#      '107': 7,
#      '108': 47,
#      '109': 54,
#      '110': 18,
#      '111': 10,
#      '112': 1,
#      '113': 1,
#      '114': 18,
#      '115': 45,
#      '116': 1,
#      '118': 4,
#      '119': 1,
#      '120': 24,
#      '122': 1,
#      '126': 24,
#      '127': 370,
#      '132': 1,
#      '137': 370,
#      '94': 1,
#      '95': 1,
#      '96': 1,
#      '99': 4}},
#    'isQueuedWaiverLocked': False,
#    'isTradeLocked': False,
#    'lockStatus': 4,
#    'opponentProTeamId': 9,
#    'player': {'defaultPositionId': 16,
#     'draftRank': 131.2,
#     'droppable': True,
#     'eligibleSlotCategoryIds': [16, 20],
#     'firstName': 'Bears',
#     'gameStarterStatus': -2147483648,
#     'healthStatus': 0,
#     'isActive': True,
#     'isIREligible': False,
#     'lastName': 'D/ST',
#     'lastNewsDate': '2012-11-06T19:22:25.114Z',
#     'lastVideoDate': '1970-01-01T00:00:00.000Z',
#     'percentChange': 0.13236,
#     'percentOwned': 97.58416,
#     'percentStarted': 93.66091,
#     'playerId': 60003,
#     'playerRatingSeason': 138,
#     'positionRank': 1,
#     'proTeamId': 3,
#     'sportsId': 60003,
#     'tickerId': 0,
#     'totalPoints': 138,
#     'universeId': 2,
#     'value': -1},
#    'proGameIds': [380909009],
#    'pvoRank': 13,
#    'slotCategoryId': 20,
#    'watchList': False}],
#  'team': {'division': {'divisionId': 0, 'divisionName': 'East', 'size': 5},
#   'divisionStanding': 5,
#   'logoType': 'vector',
#   'logoUrl': 'http://g.espncdn.com/lm-static/logo-packs/ffl/CoachGruden-ChipWass/gruden-15.svg',
#   'overallStanding': 9,
#   'teamAbbrev': 'dumb',
#   'teamId': 5,
#   'teamLocation': 'Domestic',
#   'teamNickname': 'Violins',
#   'waiverRank': 2},
#  'teamId': 5}

# %%
len(box_scores[1][0]['teams'][0]['slots'])
# Out:
# 17

# %%
box_scores[1][0]['teams'][0]['slots'][0].keys()
# Out:
# dict_keys(['currentPeriodRealStats', 'lockStatus', 'currentPeriodProjectedStats', 'proGameIds', 'opponentProTeamId', 'isQueuedWaiverLocked', 'isTradeLocked', 'watchList', 'pvoRank', 'slotCategoryId', 'player'])

# %%
box_scores[1][0]['teams'][0]['slots'][0]
# Out:
# {'currentPeriodProjectedStats': {'appliedStatTotal': 16,
#   'appliedStats': {'19': 0.1,
#    '20': -1.2,
#    '24': 2.9,
#    '25': 0.9,
#    '26': 0,
#    '4': 5.8,
#    '63': 0,
#    '72': -0.6,
#    '8': 8},
#   'rawStats': {'0': 30.54477,
#    '1': 18.93006,
#    '10': 2,
#    '11': 3,
#    '12': 1,
#    '13': 2,
#    '14': 1,
#    '15': 0.16335,
#    '16': 0.10675,
#    '17': 0.13589,
#    '18': 0.01836,
#    '19': 0.06952,
#    '2': 11.61471,
#    '20': 0.5958,
#    '21': 0.61975,
#    '22': 217.84802,
#    '23': 5.75456,
#    '24': 28.70874,
#    '25': 0.15529,
#    '26': 0.00584,
#    '27': 5,
#    '28': 2,
#    '29': 1,
#    '3': 217.84802,
#    '30': 1,
#    '33': 1,
#    '35': 0.01112,
#    '36': 0.00778,
#    '37': 0.03594,
#    '38': 0.00123,
#    '39': 4.98887,
#    '4': 1.44477,
#    '40': 28.70874,
#    '5': 43,
#    '6': 21,
#    '62': 0.07536,
#    '63': 0.00235,
#    '64': 2.77354,
#    '65': 0.51046,
#    '66': 0.08816,
#    '68': 0.59862,
#    '69': 0.24502,
#    '7': 10,
#    '70': 0.04056,
#    '72': 0.28558,
#    '73': 0.88138,
#    '8': 8,
#    '9': 4}},
#  'currentPeriodRealStats': {'appliedStatTotal': 19.5,
#   'appliedStats': {'20': -4, '24': 0.5, '4': 12, '8': 11},
#   'rawStats': {'0': 33,
#    '1': 19,
#    '10': 2,
#    '11': 3,
#    '12': 1,
#    '13': 2,
#    '14': 1,
#    '15': 1,
#    '156': 1,
#    '16': 1,
#    '2': 14,
#    '20': 2,
#    '21': 0.57576,
#    '22': 298,
#    '23': 2,
#    '24': 5,
#    '27': 1,
#    '3': 298,
#    '39': 2.5,
#    '4': 3,
#    '40': 5,
#    '5': 59,
#    '6': 29,
#    '64': 6,
#    '65': 1,
#    '66': 1,
#    '68': 2,
#    '7': 14,
#    '73': 2,
#    '8': 11,
#    '9': 5}},
#  'isQueuedWaiverLocked': False,
#  'isTradeLocked': False,
#  'lockStatus': 4,
#  'opponentProTeamId': 7,
#  'player': {'defaultPositionId': 1,
#   'draftRank': 56.2,
#   'droppable': True,
#   'eligibleSlotCategoryIds': [0, 20],
#   'firstName': 'Russell',
#   'gameStarterStatus': -2147483648,
#   'healthStatus': 0,
#   'isActive': True,
#   'isIREligible': False,
#   'jersey': '3',
#   'lastName': 'Wilson',
#   'lastNewsDate': '2018-11-25T21:17:22.000Z',
#   'lastVideoDate': '2018-02-22T19:27:21.323Z',
#   'percentChange': 1.38826,
#   'percentOwned': 90.22335,
#   'percentStarted': 53.85998,
#   'playerId': 14881,
#   'playerRatingSeason': 203.5,
#   'positionRank': 13,
#   'proTeamId': 26,
#   'sportsId': 14881,
#   'tickerId': 2268321,
#   'totalPoints': 203.5,
#   'universeId': 2,
#   'value': -1},
#  'proGameIds': [380909007],
#  'pvoRank': 14,
#  'slotCategoryId': 0,
#  'watchList': False}

# %%
# this identifies the positions (i.e. 0 = QB)
[slot['slotCategoryId'] for slot in box_scores[1][0]['teams'][0]['slots']]
# Out:
# [0, 2, 2, 4, 4, 6, 23, 23, 16, 17, 20, 20, 20, 20, 20, 20, 20]

# %% [markdown]
# Should build dataframe (for the purpose of showing season performance) with columns:
#
# team, week, opponent, point_total, slot_id, slot_category, slot_point_total, player, player_position

# %%
data = []
for week, week_scores in box_scores.items():
    matchups = [ws['scheduleItems'][0]['matchups'] for ws in week_scores.values()]
    team_scores = [t for ws in week_scores.values() for t in ws['teams']]
    for team_score in team_scores:
        team_id = team_score['teamId']
        team_point_total = team_score['appliedActiveRealTotal']
        slot_index = 0
        for slot in team_score['slots']:
            slot_data = [team_id, week, team_point_total, slot_index, slot['slotCategoryId']]
            if 'currentPeriodRealStats' in slot.keys() and 'appliedStatTotal' in slot['currentPeriodRealStats'].keys():
                slot_data.append(slot['currentPeriodRealStats']['appliedStatTotal'])
            else:
                slot_data.append(0)
            if 'player' in slot.keys():
                slot_data.append(slot['player']['firstName'] + ' ' + slot['player']['lastName'])
                slot_data.append(slot['player']['defaultPositionId'])
            else:
                slot_data += [np.nan, np.nan]

            slot_df = pd.DataFrame([slot_data], columns=['team_id', 'week', 'team_point_total',
                                                         'slot_index', 'slot_category', 'slot_point_total',
                                                         'player_name', 'player_position'])
            data.append(slot_df)
            slot_index += 1
score_df = pd.concat(data, axis=0)

# %%
score_df
# Out:
#     team_id  week  team_point_total  slot_index  slot_category  \
# 0         5     1             133.4           0              0
# 0         5     1             133.4           1              2
# 0         5     1             133.4           2              2
# 0         5     1             133.4           3              4
# 0         5     1             133.4           4              4
# 0         5     1             133.4           5              6
# 0         5     1             133.4           6             23
# 0         5     1             133.4           7             23
# 0         5     1             133.4           8             16
# 0         5     1             133.4           9             17
# 0         5     1             133.4          10             20
# 0         5     1             133.4          11             20
# 0         5     1             133.4          12             20
# 0         5     1             133.4          13             20
# 0         5     1             133.4          14             20
# 0         5     1             133.4          15             20
# 0         5     1             133.4          16             20
# 0         8     1             139.8           0              0
# 0         8     1             139.8           1              2
# 0         8     1             139.8           2              2
# 0         8     1             139.8           3              4
# 0         8     1             139.8           4              4
# 0         8     1             139.8           5              6
# 0         8     1             139.8           6             23
# 0         8     1             139.8           7             23
# 0         8     1             139.8           8             16
# 0         8     1             139.8           9             17
# 0         8     1             139.8          10             20
# 0         8     1             139.8          11             20
# 0         8     1             139.8          12             20
# ..      ...   ...               ...         ...            ...
# 0        10    13               0.0           4              4
# 0        10    13               0.0           5              6
# 0        10    13               0.0           6             23
# 0        10    13               0.0           7             23
# 0        10    13               0.0           8             16
# 0        10    13               0.0           9             17
# 0        10    13               0.0          10             20
# 0        10    13               0.0          11             20
# 0        10    13               0.0          12             20
# 0        10    13               0.0          13             20
# 0        10    13               0.0          14             20
# 0        10    13               0.0          15             20
# 0        10    13               0.0          16             20
# 0         7    13               0.0           0              0
# 0         7    13               0.0           1              2
# 0         7    13               0.0           2              2
# 0         7    13               0.0           3              4
# 0         7    13               0.0           4              4
# 0         7    13               0.0           5              6
# 0         7    13               0.0           6             23
# 0         7    13               0.0           7             23
# 0         7    13               0.0           8             16
# 0         7    13               0.0           9             17
# 0         7    13               0.0          10             20
# 0         7    13               0.0          11             20
# 0         7    13               0.0          12             20
# 0         7    13               0.0          13             20
# 0         7    13               0.0          14             20
# 0         7    13               0.0          15             20
# 0         7    13               0.0          16             20
#
#     slot_point_total          player_name  player_position
# 0               19.5       Russell Wilson              1.0
# 0               22.2       Todd Gurley II              2.0
# 0                2.6         LeSean McCoy              2.0
# 0               38.8          Tyreek Hill              3.0
# 0                8.9       Nelson Agholor              3.0
# 0                1.8         Jimmy Graham              4.0
# 0                3.8         Mohamed Sanu              3.0
# 0                6.8            John Ross              3.0
# 0               13.0         Jaguars D/ST             16.0
# 0               16.0        Greg Zuerlein              5.0
# 0                3.5        C.J. Anderson              2.0
# 0               21.8       Chris Thompson              2.0
# 0                1.6         Josh Doctson              3.0
# 0                4.2      Latavius Murray              2.0
# 0               12.0           John Brown              3.0
# 0               13.2    Mitchell Trubisky              1.0
# 0               13.0           Bears D/ST             16.0
# 0               21.2            Tom Brady              1.0
# 0               38.6         Alvin Kamara              2.0
# 0               10.5          Dalvin Cook              2.0
# 0               11.1     Larry Fitzgerald              3.0
# 0               14.1        Jarvis Landry              3.0
# 0                2.0          Trey Burton              4.0
# 0               20.2            Jay Ajayi              2.0
# 0                3.1        Pierre Garcon              3.0
# 0               15.0            Rams D/ST             16.0
# 0                4.0         Jake Elliott              5.0
# 0                7.3     Sterling Shepard              3.0
# 0                2.6        Corey Clement              2.0
# 0                8.6      Jimmy Garoppolo              1.0
# ..               ...                  ...              ...
# 0                0.0  JuJu Smith-Schuster              3.0
# 0                0.0            Zach Ertz              4.0
# 0                0.0         Robert Woods              3.0
# 0                0.0          Gus Edwards              2.0
# 0                0.0         Packers D/ST             16.0
# 0                0.0   Stephen Gostkowski              5.0
# 0                0.0         Randall Cobb              3.0
# 0                0.0        Blake Bortles              1.0
# 0                0.0     Courtland Sutton              3.0
# 0                0.0           Bills D/ST             16.0
# 0                0.0           Mike Davis              2.0
# 0                0.0     Duke Johnson Jr.              2.0
# 0                0.0        Mike Williams              3.0
# 0                0.0           Jared Goff              1.0
# 0                0.0       Saquon Barkley              2.0
# 0                0.0           Nick Chubb              2.0
# 0                0.0          T.Y. Hilton              3.0
# 0                0.0     Emmanuel Sanders              3.0
# 0                0.0         Kyle Rudolph              4.0
# 0                0.0         Amari Cooper              3.0
# 0                0.0          James White              2.0
# 0                0.0        Redskins D/ST             16.0
# 0                0.0       Adam Vinatieri              5.0
# 0                0.0    Leonard Fournette              2.0
# 0                0.0       Isaiah Crowell              2.0
# 0                0.0           Tyler Boyd              3.0
# 0                0.0             DJ Moore              3.0
# 0                0.0       Jameis Winston              1.0
# 0                0.0          Carlos Hyde              2.0
# 0                0.0       Devin Funchess              3.0
#
# [2211 rows x 8 columns]

# %%
# mean score by position
score_df.groupby(['team_id', 'player_position']).slot_point_total.mean()
# Out:
# team_id  player_position
# 1        1.0                16.603846
#          2.0                 8.914141
#          3.0                 8.709434
#          4.0                11.406667
#          5.0                 8.642857
#          16.0                4.923077
# 2        1.0                17.903448
#          2.0                11.321875
#          3.0                 9.184416
#          4.0                 6.656000
#          5.0                 7.769231
#          16.0                3.615385
# 3        1.0                16.123810
#          2.0                 7.829577
#          3.0                 9.840385
#          4.0                 7.045833
#          5.0                 7.125000
#          16.0                8.687500
# 4        1.0                14.547059
#          2.0                 7.766667
#          3.0                 9.339706
#          4.0                 5.534286
#          5.0                 7.500000
#          16.0                4.937500
# 5        1.0                16.195000
#          2.0                 8.408772
#          3.0                 9.271605
#          4.0                 5.533333
#          5.0                 6.117647
#          16.0                7.074074
# 6        1.0                13.907692
#          2.0                 9.910000
#          3.0                 8.886598
#          4.0                 5.325000
#          5.0                 4.307692
#          16.0                6.800000
# 7        1.0                17.073333
#          2.0                11.168657
#          3.0                 8.074194
#          4.0                 5.875000
#          5.0                 5.307692
#          16.0                5.230769
# 8        1.0                13.920000
#          2.0                 9.589706
#          3.0                 8.484058
#          4.0                 8.380769
#          5.0                 6.391304
#          16.0                5.800000
# 9        1.0                19.459259
#          2.0                 9.158333
#          3.0                 8.808065
#          4.0                 9.137500
#          5.0                 8.000000
#          16.0                3.483871
# 10       1.0                15.504000
#          2.0                 7.294915
#          3.0                 8.298889
#          4.0                10.737500
#          5.0                 6.692308
#          16.0                2.588235
# Name: slot_point_total, dtype: float64

# %%
# for only starters
starter_scores = score_df[score_df.slot_index <= 10]
position_means = starter_scores.groupby('player_position').slot_point_total.mean().reset_index().rename(
    columns={'slot_point_total':'mean_position_point_total'})

# %%
position_means
# Out:
#    player_position  mean_position_point_total
# 0              1.0                  18.354422
# 1              2.0                  11.071655
# 2              3.0                  11.171296
# 3              4.0                   8.474306
# 4              5.0                   7.092308
# 5             16.0                   6.118519

# %%
team_position_means = starter_scores.groupby(
    ['team_id', 'player_position']).slot_point_total.mean().reset_index()

# %%
team_position_means
# Out:
#     team_id  player_position  slot_point_total
# 0         1              1.0         22.107692
# 1         1              2.0         11.791667
# 2         1              3.0         11.866667
# 3         1              4.0         12.221429
# 4         1              5.0          9.307692
# 5         1             16.0          4.923077
# 6         2              1.0         20.215385
# 7         2              2.0         13.184091
# 8         2              3.0         11.427660
# 9         2              4.0          6.915385
# 10        2              5.0          7.769231
# 11        2             16.0          3.615385
# 12        3              1.0         17.938462
# 13        3              2.0          9.818367
# 14        3              3.0         11.930769
# 15        3              4.0          8.843750
# 16        3              5.0          8.538462
# 17        3             16.0          9.461538
# 18        4              1.0         16.692308
# 19        4              2.0          8.877273
# 20        4              3.0         12.042222
# 21        4              4.0          8.313333
# 22        4              5.0          7.923077
# 23        4             16.0          5.538462
# 24        5              1.0         16.122222
# 25        5              2.0         11.442424
# 26        5              3.0         11.206250
# 27        5              4.0          6.614286
# 28        5              5.0          8.000000
# 29        5             16.0          8.000000
# 30        6              1.0         14.186667
# 31        6              2.0         11.424324
# 32        6              3.0         11.526531
# 33        6              4.0          5.643750
# 34        6              5.0          4.307692
# 35        6             16.0          7.846154
# 36        7              1.0         19.700000
# 37        7              2.0         13.273333
# 38        7              3.0         10.743478
# 39        7              4.0          5.930769
# 40        7              5.0          5.307692
# 41        7             16.0          5.230769
# 42        8              1.0         16.726667
# 43        8              2.0         10.570000
# 44        8              3.0          8.671795
# 45        8              4.0          8.853846
# 46        8              5.0          5.384615
# 47        8             16.0          6.692308
# 48        9              1.0         21.752632
# 49        9              2.0         11.369767
# 50        9              3.0         10.310526
# 51        9              4.0          9.746667
# 52        9              5.0          7.692308
# 53        9             16.0          5.285714
# 54       10              1.0         18.293333
# 55       10              2.0          8.563889
# 56       10              3.0         11.741176
# 57       10              4.0         11.453333
# 58       10              5.0          6.692308
# 59       10             16.0          4.076923

# %%
merged = pd.merge(team_position_means, position_means, on='player_position')

# %%
merged.plot(kind='scatter', x='team_id', y='slot_point_total', )

# %%
points_per_player = score_df.groupby(['team_id', 'player_name']).slot_point_total.sum()
points_per_player.groupby('team_id').apply(lambda x: x.sort_values(ascending=False).head(7))
# Out:
# team_id  team_id  player_name
# 1        1        Drew Brees             253.0
#                   Melvin Gordon          229.5
#                   Julio Jones            187.7
#                   Travis Kelce           166.9
#                   Aaron Jones            126.3
#                   Wil Lutz               121.0
#                   Cooper Kupp            115.1
# 2        2        Matt Ryan              248.7
#                   Andrew Luck            234.5
#                   Michael Thomas         195.0
#                   Todd Gurley II         177.2
#                   Adrian Peterson        139.5
#                   Tevin Coleman          133.9
#                   A.J. Green             125.2
# 3        3        Ben Roethlisberger     243.8
#                   James Conner           220.7
#                   Philip Rivers          214.9
#                   Adam Thielen           210.3
#                   Keenan Allen           148.8
#                   Phillip Lindsay        133.5
#                   T.J. Yeldon            117.4
# 4        4        Deshaun Watson         213.5
#                   DeAndre Hopkins        182.2
#                   Odell Beckham Jr.      174.6
#                   Joe Mixon              143.1
#                   Matt Breida            126.6
#                   Alex Collins           101.1
#                   Justin Tucker          100.0
# 5        5        Tyreek Hill            223.2
#                   Russell Wilson         203.5
#                                          ...
# 6        6        DeSean Jackson         127.5
#                   Dion Lewis             105.4
# 7        7        Saquon Barkley         250.5
#                   Jared Goff             185.3
#                   Emmanuel Sanders       158.7
#                   James White            155.0
#                   T.Y. Hilton            129.5
#                   Isaiah Crowell         116.3
#                   Amari Cooper           109.8
# 8        8        Alvin Kamara           245.0
#                   Tom Brady              189.8
#                   Tyler Lockett          140.4
#                   Sterling Shepard       107.7
#                   Jarvis Landry          107.0
#                   Eric Ebron             103.4
#                   Larry Fitzgerald       100.0
# 9        9        Patrick Mahomes        296.6
#                   Christian McCaffrey    230.0
#                   Aaron Rodgers          213.8
#                   Antonio Brown          188.9
#                   Kenyan Drake           129.6
#                   Kenny Golladay         122.3
#                   George Kittle          119.8
# 10       10       Cam Newton             246.7
#                   Mike Evans             172.3
#                   JuJu Smith-Schuster    171.3
#                   Zach Ertz              167.5
#                   David Johnson          162.7
#                   Robert Woods           155.0
#                   Will Fuller V           90.3
# Name: slot_point_total, Length: 70, dtype: float64
