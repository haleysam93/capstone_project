# %%
import requests as r

# %%
resp = r.get(url="https://api.github.com/users/haleysam93/repos")

# %%
resp.json()
# Out:
# [{'archive_url': 'https://api.github.com/repos/haleysam93/beer_description_generator/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/haleysam93/beer_description_generator/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/haleysam93/beer_description_generator/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/haleysam93/beer_description_generator/branches{/branch}',
#   'clone_url': 'https://github.com/haleysam93/beer_description_generator.git',
#   'collaborators_url': 'https://api.github.com/repos/haleysam93/beer_description_generator/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/haleysam93/beer_description_generator/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/haleysam93/beer_description_generator/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/haleysam93/beer_description_generator/compare/{base}...{head}',
# ...
